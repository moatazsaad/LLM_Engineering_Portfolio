# %%
# Importing libraries
from openai import OpenAI
import anthropic
from IPython.display import display,Markdown,update_display
from dotenv import load_dotenv
from bs4 import BeautifulSoup
import requests
import os
from typing import List
import json
import gradio as gr

# %%
# Load environment variables from the .env file
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')

# %%
# Initialize OpenAI and Claude clients
openai = OpenAI()
claude = anthropic.Anthropic()

# %%
# Website class for extracting title, text, and links from a webpage
class Website:
    link: List[str]
    text:str
    url :str
    body :str
    title: str
    
    def __init__(self,url):
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "no title"
        if soup.body:
            for irrelevant in soup.body(["script","style","img","input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator='\n', strip = True)
        else:
            self.text = ""
        self.links = [link.get('href') for link in soup.find_all('a') if link.get('href')]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}"

# %%
nvidia = Website("https://www.nvidia.com/en-me/")
nvidia.links
# Out:
# ['https://www.nvidia.com',
#  '#page-content',
#  'https://www.nvidia.com/en-me/geforce/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-me/geforce/laptops/',
#  'https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/',
#  'https://www.nvidia.com/en-me/studio/laptops-desktops/',
#  'https://www.nvidia.com/en-eu/shield/',
#  'https://www.nvidia.com/en-me/ai-on-rtx/',
#  'https://www.nvidia.com/en-me/geforce/laptops/',
#  'https://www.nvidia.com/en-eu/design-visualization/desktop-graphics/',
#  'https://www.nvidia.com/en-eu/design-visualization/rtx-professional-laptops/',
#  'https://www.nvidia.com/en-eu/data-center/dgx-station/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-eu/data-center/grace-cpu/',
#  'https://www.nvidia.com/en-eu/data-center/dgx-platform/',
#  'https://www.nvidia.com/en-eu/data-center/products/egx/',
#  'https://www.nvidia.com/en-eu/edge-computing/products/igx/',
#  'https://www.nvidia.com/en-eu/data-center/hgx/',
#  'https://www.nvidia.com/en-eu/data-center/products/mgx/',
#  'https://www.nvidia.com/en-eu/omniverse/platform/ovx/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/simulation/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/networking/products/data-processing-unit/',
#  'https://www.nvidia.com/en-eu/networking/products/ethernet',
#  'https://www.nvidia.com/en-eu/networking/products/infiniband/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-eu/design-visualization/rtx/',
#  'https://www.nvidia.com/en-us/data-center/nvidia-ampere-gpu-architecture/',
#  'https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/hardware/',
#  'https://www.nvidia.com/en-eu/clara/medical-devices/',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/self-driving-cars/software',
#  'https://developer.nvidia.com/MAXINE',
#  'https://developer.nvidia.com/culitho',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu//deep-learning-ai/software/rapids',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework',
#  'https://www.nvidia.com/en-eu/clara',
#  'https://developer.nvidia.com/hpc-sdk',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-omniverse-platform',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://developer.nvidia.com/isaac-ros',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://developer.nvidia.com/aerial-sdk',
#  'https://www.nvidia.com/en-eu/gpu-accelerated-applications/',
#  'https://catalog.ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/gpu-cloud/',
#  'https://www.nvidia.com/en-eu/design-visualization/omniverse/',
#  'https://www.nvidia.com/en-eu/data-center/enterprise-software/',
#  'https://developer.nvidia.com/dcgm',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/',
#  'https://www.nvidia.com/en-eu/studio/software/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/broadcast-app/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench/',
#  'https://www.nvidia.com/en-eu/geforce-now/home',
#  'https://www.nvidia.com/en-me/geforce/geforce-experience/',
#  'https://www.nvidia.com/en-me/geforce/broadcasting/',
#  'https://www.nvidia.com/en-eu/omniverse/apps/machinima/',
#  'https://www.nvidia.com/en-me/geforce/rtx-remix/',
#  'https://www.nvidia.com/en-me/studio/resources/',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/',
#  'https://developer.nvidia.com/egx-stack',
#  'https://developer.nvidia.com/cluster-management',
#  'https://www.nvidia.com/en-eu/data-center/magnum-io/',
#  'https://www.nvidia.com/en-eu/networking/products/software/',
#  'https://www.nvidia.com/en-eu/data-center/virtual-solutions/',
#  'https://www.nvidia.com/en-eu/data-center/base-command',
#  'https://www.nvidia.com/en-eu/clara/bionemo',
#  'https://www.nvidia.com/en-eu/gpu-cloud/nemo-llm-service',
#  'https://www.nvidia.com/en-eu/gpu-cloud/picasso',
#  'https://docs.nvidia.com/ngc/ngc-private-registry-user-guide/index.html',
#  'https://www.nvidia.com/en-eu/omniverse/cloud',
#  'https://www.nvidia.com/en-eu/ai',
#  'https://www.nvidia.com/en-eu/ai-data-science/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai',
#  'https://www.nvidia.com/en-eu/solutions/ai/cybersecurity/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting',
#  'https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/data-center/colocation-partners/',
#  'https://www.nvidia.com/en-eu/data-center/edge-computing/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/data-center/virtualization/',
#  'https://www.nvidia.com/en-eu/data-center/solutions/mlops/',
#  'https://www.nvidia.com/en-eu/solutions/design-and-simulation/',
#  'https://www.nvidia.com/en-eu/omniverse/solutions/digital-twins/',
#  'https://www.nvidia.com/en-eu/design-visualization/',
#  'https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/',
#  'https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics',
#  'https://www.nvidia.com/en-eu/edge-computing',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/high-performance-computing/',
#  'https://www.nvidia.com/en-eu/high-performance-computing/hpc-and-ai/',
#  'https://www.nvidia.com/en-eu/high-performance-computing/scientific-visualization',
#  'https://www.nvidia.com/en-eu/high-performance-computing/simulation-and-modeling',
#  'https://www.nvidia.com/en-eu/solutions/quantum-computing',
#  'https://www.nvidia.com/en-eu/self-driving-cars/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing',
#  'https://www.nvidia.com/en-eu/self-driving-cars/infrastructure',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://www.nvidia.com/en-eu/industries/aec/',
#  'https://www.nvidia.com/en-eu/industries/automotive/',
#  'https://www.nvidia.com/en-eu/industries/consumer-internet/',
#  'https://www.nvidia.com/en-eu/industries/energy/',
#  'https://www.nvidia.com/en-eu/industries/finance/',
#  'https://www.nvidia.com/en-eu/industries/game-development/',
#  'https://www.nvidia.com/en-eu/industries/global-public-sector/',
#  'https://www.nvidia.com/en-eu/industries/healthcare/',
#  'https://www.nvidia.com/en-eu/industries/higher-education-research/',
#  'https://www.nvidia.com/en-eu/industries/industrial-sector/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/industries/media-and-entertainment/',
#  'https://www.nvidia.com/en-eu/industries/restaurants/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/industries/robotics/',
#  'https://www.nvidia.com/en-eu/industries/smart-cities-and-spaces/',
#  'https://www.nvidia.com/en-eu/industries/supercomputing/',
#  'https://www.nvidia.com/en-eu/industries/telecommunications/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  'https://www.nvidia.com/en-eu/executive-insights/',
#  'https://www.nvidia.com/en-us/programs/isv/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://www.nvidia.com/en-eu/studio/',
#  'https://www.nvidia.com/en-eu/studio/software/',
#  'https://www.nvidia.com/en-eu/studio/products/',
#  'https://www.nvidia.com/en-eu/studio/compare-gpus/',
#  'https://www.nvidia.com/en-us/studio/shop/',
#  'https://www.nvidia.com/en-us/design-visualization/industries/media-entertainment/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/design-visualization/industries/architecture-engineering-construction/',
#  'https://www.nvidia.com/en-eu/industries',
#  'https://www.nvidia.com/en-us/design-visualization/quadro-servers/rtx/',
#  'https://www.nvidia.com/en-eu/design-visualization/quadro/',
#  'https://www.nvidia.com/en-us/design-visualization/solutions/quadro-vr/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/quadro-display-desktop-management/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/rendering',
#  'https://www.nvidia.com/en-eu/design-visualization/omniverse/',
#  'https://www.nvidia.com/en-us/design-visualization/quadro-vdws/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/engineering-simulation/',
#  'https://www.nvidia.com/en-eu/industries/finance/',
#  'https://www.nvidia.com/en-eu/industries/consumer-internet/',
#  'https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/higher-education-research/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/training',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting',
#  'https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://developer.nvidia.com/nvidia-omniverse-platform/ace/tokkio-showcase',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/apache-spark-3',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://www.nvidia.com/en-eu/gpu-cloud',
#  'https://catalog.ngc.nvidia.com/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/products/titan-rtx/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/ai-data-science/professional-services/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://resources.nvidia.com/l/en-us-data-science',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://developer.nvidia.com/blog/category/data-science/',
#  'https://www.nvidia.com/en-eu/ai-data-science/kaggle-grandmasters/',
#  'https://developer.nvidia.com/join',
#  'https://ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://news.developer.nvidia.com/',
#  'https://developer.nvidia.com/blog',
#  'https://forums.developer.nvidia.com/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-us/gtc/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://developer.nvidia.com/',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://developer.nvidia.com/drive',
#  'https://developer.nvidia.com/MAXINE',
#  'https://developer.nvidia.com/culitho',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids',
#  'https://developer.nvidia.com/generative-ai',
#  'https://www.nvidia.com/en-eu/clara',
#  'https://developer.nvidia.com/hpc-sdk',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-omniverse-platform',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://developer.nvidia.com/isaac',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://developer.nvidia.com/aerial-sdk',
#  'https://developer.nvidia.com/cuda-zone',
#  'https://developer.nvidia.com/embedded/jetpack',
#  'https://developer.nvidia.com/networking/doca',
#  'https://developer.nvidia.com/gpu-accelerated-libraries',
#  'https://developer.nvidia.com/tensorrt',
#  'https://developer.nvidia.com/cudnn',
#  'https://developer.nvidia.com/deep-learning-frameworks',
#  'https://developer.nvidia.com/nvidia-nemo',
#  'https://developer.nvidia.com/deepstream-sdk',
#  'https://developer.nvidia.com/unrealengine',
#  'https://developer.nvidia.com/rtx',
#  'https://developer.nvidia.com/nvidia-video-codec-sdk',
#  'https://developer.nvidia.com/drive/driveworks',
#  'https://www.nvidia.com/en-me/geforce/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-me/geforce/gaming-laptops/',
#  'https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/',
#  'https://www.nvidia.com/en-me/geforce/20-series/rtx/',
#  'https://www.nvidia.com/en-me/geforce/geforce-experience/',
#  'https://www.nvidia.com/en-us/geforce/drivers/',
#  'https://www.nvidia.com/en-us/geforce/forums/discover/',
#  'https://www.nvidia.com/en-us/geforce/support/',
#  'https://www.nvidia.com/en-me/geforce/buy/',
#  'https://www.nvidia.com/en-eu/geforce-now/',
#  'https://www.nvidia.com/en-eu/geforce-now/download/',
#  'https://www.nvidia.com/en-eu/geforce-now/games/',
#  'https://www.nvidia.com/en-eu/geforce-now/memberships/',
#  'https://www.nvidia.com/en-eu/geforce-now/faq/',
#  'https://forums.geforce.com/default/board/199/geforce-now-for-mac-beta/',
#  'https://www.nvidia.com/en-eu/geforce-now/support/',
#  'https://www.nvidia.com/en-us/shield/',
#  'https://www.nvidia.com/en-us/shield/compare/',
#  'https://shop.nvidia.com/en-us/shield/',
#  'https://nvidia.custhelp.com/app/answers/detail/a_id/4732',
#  'https://nvidia.custhelp.com/app/shield/st/5/p/178/page/1/',
#  'https://www.nvidia.com/en-me/geforce/campaigns/back-to-school/?nvid=nv-int-bnr-719151#cid=_nv-int-bnr_en-me',
#  'https://www.nvidia.com/en-us/deep-learning-ai/solutions/on-premises/',
#  'https://www.nvidia.com/en-eu/data-center/edge-computing/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/data-center/virtualization/',
#  'https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/',
#  'https://developer.nvidia.com/egx-stack',
#  'https://developer.nvidia.com/cluster-management',
#  'https://www.nvidia.com/en-eu/data-center/products/fleet-command/',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/data-center/magnum-io/',
#  'https://www.nvidia.com/en-eu/networking/products/software/',
#  'https://www.nvidia.com/en-eu/data-center/virtual-solutions/',
#  'https://www.nvidia.com/en-us/data-center/software/',
#  'https://developer.nvidia.com/dcgm',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/',
#  'https://www.nvidia.com/en-eu/data-center/resources/',
#  'https://academy.nvidia.com/en/',
#  'https://www.nvidia.com/en-eu/support/enterprise/',
#  'https://www.nvidia.com/Download/index.aspx?lang=en-us',
#  'https://www.nvidia.com/en-eu/security/',
#  'https://docs.nvidia.com/',
#  'https://forums.developer.nvidia.com/',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://www.nvidia.com/en-us/research/research-areas/',
#  'https://www.nvidia.com/en-eu/research/ai-playground/',
#  'https://www.youtube.com/user/NVIDIADeveloper',
#  'https://developer.nvidia.com/research/covid-19',
#  'https://ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://www.nvidia.com/en-us/research/news/',
#  'https://developer.nvidia.com/blog/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/cambridge-1/',
#  'https://www.nvidia.com/en-eu/data-center/dgx-systems/',
#  'https://www.nvidia.com/en-eu/data-center/products/egx/',
#  'https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/jetson-xavier-nx/',
#  'https://developer.nvidia.com/isaac-ros',
#  'https://developer.nvidia.com/isaac-sim',
#  'https://developer.nvidia.com/transfer-learning-toolkit',
#  'https://developer.nvidia.com/deepstream-sdk',
#  'https://www.nvidia.com/en-eu/data-center/products/fleet-command/',
#  'https://developer.nvidia.com/nvidia-omniverse-platform/replicator',
#  'https://www.nvidia.com/en-eu/industries/healthcare/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics/',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://blogs.nvidia.com/blog/category/robotics/',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://developer.nvidia.com/blog?r=1&tags=&categories=robotics',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://shop.nvidia.com/en-us/',
#  'https://www.nvidia.com/Download/index.aspx?lang=en-us',
#  'https://www.nvidia.com/en-eu/support/',
#  '#',
#  '#',
#  'https://www.nvidia.co.uk/account/edit-profile',
#  '#',
#  '#',
#  '#page-content',
#  '#',
#  '#',
#  'https://www.nvidia.com/en-me/geforce/',
#  '/',
#  'https://www.nvidia.co.uk/account/edit-profile',
#  '#',
#  '#',
#  '#nav-lvl1-tab1',
#  '#nav-lvl1-tab1-lvl2-tab1',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-me/geforce/laptops/',
#  'https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/',
#  'https://www.nvidia.com/en-me/studio/laptops-desktops/',
#  'https://www.nvidia.com/en-eu/shield/',
#  'https://www.nvidia.com/en-me/ai-on-rtx/',
#  'https://www.nvidia.com/en-me/geforce/laptops/',
#  'https://www.nvidia.com/en-eu/design-visualization/desktop-graphics/',
#  'https://www.nvidia.com/en-eu/design-visualization/rtx-professional-laptops/',
#  'https://www.nvidia.com/en-eu/data-center/dgx-station/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-eu/data-center/grace-cpu/',
#  'https://www.nvidia.com/en-eu/data-center/dgx-platform/',
#  'https://www.nvidia.com/en-eu/data-center/products/egx/',
#  'https://www.nvidia.com/en-eu/edge-computing/products/igx/',
#  'https://www.nvidia.com/en-eu/data-center/hgx/',
#  'https://www.nvidia.com/en-eu/data-center/products/mgx/',
#  'https://www.nvidia.com/en-eu/omniverse/platform/ovx/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/simulation/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/networking/products/data-processing-unit/',
#  'https://www.nvidia.com/en-eu/networking/products/ethernet',
#  'https://www.nvidia.com/en-eu/networking/products/infiniband/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-eu/design-visualization/rtx/',
#  'https://www.nvidia.com/en-us/data-center/nvidia-ampere-gpu-architecture/',
#  'https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/hardware/',
#  'https://www.nvidia.com/en-eu/clara/medical-devices/',
#  '#nav-lvl1-tab1-lvl2-tab2',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/self-driving-cars/software',
#  'https://developer.nvidia.com/MAXINE',
#  'https://developer.nvidia.com/culitho',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu//deep-learning-ai/software/rapids',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework',
#  'https://www.nvidia.com/en-eu/clara',
#  'https://developer.nvidia.com/hpc-sdk',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-omniverse-platform',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://developer.nvidia.com/isaac-ros',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://developer.nvidia.com/aerial-sdk',
#  'https://www.nvidia.com/en-eu/gpu-accelerated-applications/',
#  'https://catalog.ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/gpu-cloud/',
#  'https://www.nvidia.com/en-eu/design-visualization/omniverse/',
#  'https://www.nvidia.com/en-eu/data-center/enterprise-software/',
#  'https://developer.nvidia.com/dcgm',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/',
#  'https://www.nvidia.com/en-eu/studio/software/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/broadcast-app/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench/',
#  'https://www.nvidia.com/en-eu/geforce-now/home',
#  'https://www.nvidia.com/en-me/geforce/geforce-experience/',
#  'https://www.nvidia.com/en-me/geforce/broadcasting/',
#  'https://www.nvidia.com/en-eu/omniverse/apps/machinima/',
#  'https://www.nvidia.com/en-me/geforce/rtx-remix/',
#  'https://www.nvidia.com/en-me/studio/resources/',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/',
#  'https://developer.nvidia.com/egx-stack',
#  'https://developer.nvidia.com/cluster-management',
#  'https://www.nvidia.com/en-eu/data-center/magnum-io/',
#  'https://www.nvidia.com/en-eu/networking/products/software/',
#  'https://www.nvidia.com/en-eu/data-center/virtual-solutions/',
#  'https://www.nvidia.com/en-eu/data-center/base-command',
#  'https://www.nvidia.com/en-eu/clara/bionemo',
#  'https://www.nvidia.com/en-eu/gpu-cloud/nemo-llm-service',
#  'https://www.nvidia.com/en-eu/gpu-cloud/picasso',
#  'https://docs.nvidia.com/ngc/ngc-private-registry-user-guide/index.html',
#  'https://www.nvidia.com/en-eu/omniverse/cloud',
#  '#nav-lvl1-tab2',
#  'https://www.nvidia.com/en-eu/ai',
#  'https://www.nvidia.com/en-eu/ai-data-science/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai',
#  'https://www.nvidia.com/en-eu/solutions/ai/cybersecurity/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting',
#  'https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/data-center/colocation-partners/',
#  'https://www.nvidia.com/en-eu/data-center/edge-computing/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/data-center/virtualization/',
#  'https://www.nvidia.com/en-eu/data-center/solutions/mlops/',
#  'https://www.nvidia.com/en-eu/solutions/design-and-simulation/',
#  'https://www.nvidia.com/en-eu/omniverse/solutions/digital-twins/',
#  'https://www.nvidia.com/en-eu/design-visualization/',
#  'https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/',
#  'https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics',
#  'https://www.nvidia.com/en-eu/edge-computing',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/high-performance-computing/',
#  'https://www.nvidia.com/en-eu/high-performance-computing/hpc-and-ai/',
#  'https://www.nvidia.com/en-eu/high-performance-computing/scientific-visualization',
#  'https://www.nvidia.com/en-eu/high-performance-computing/simulation-and-modeling',
#  'https://www.nvidia.com/en-eu/solutions/quantum-computing',
#  'https://www.nvidia.com/en-eu/self-driving-cars/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing',
#  'https://www.nvidia.com/en-eu/self-driving-cars/infrastructure',
#  '#nav-lvl1-tab3',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://www.nvidia.com/en-eu/industries/aec/',
#  'https://www.nvidia.com/en-eu/industries/automotive/',
#  'https://www.nvidia.com/en-eu/industries/consumer-internet/',
#  'https://www.nvidia.com/en-eu/industries/energy/',
#  'https://www.nvidia.com/en-eu/industries/finance/',
#  'https://www.nvidia.com/en-eu/industries/game-development/',
#  'https://www.nvidia.com/en-eu/industries/global-public-sector/',
#  'https://www.nvidia.com/en-eu/industries/healthcare/',
#  'https://www.nvidia.com/en-eu/industries/higher-education-research/',
#  'https://www.nvidia.com/en-eu/industries/industrial-sector/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/industries/media-and-entertainment/',
#  'https://www.nvidia.com/en-eu/industries/restaurants/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/industries/robotics/',
#  'https://www.nvidia.com/en-eu/industries/smart-cities-and-spaces/',
#  'https://www.nvidia.com/en-eu/industries/supercomputing/',
#  'https://www.nvidia.com/en-eu/industries/telecommunications/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  '#nav-lvl1-tab4',
#  '#nav-lvl1-tab4-lvl2-tab1',
#  'https://www.nvidia.com/en-eu/studio/',
#  'https://www.nvidia.com/en-eu/studio/software/',
#  'https://www.nvidia.com/en-eu/studio/products/',
#  'https://www.nvidia.com/en-eu/studio/compare-gpus/',
#  'https://www.nvidia.com/en-us/studio/shop/',
#  'https://www.nvidia.com/en-us/design-visualization/industries/media-entertainment/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/design-visualization/industries/architecture-engineering-construction/',
#  'https://www.nvidia.com/en-eu/industries',
#  'https://www.nvidia.com/en-us/design-visualization/quadro-servers/rtx/',
#  'https://www.nvidia.com/en-eu/design-visualization/quadro/',
#  'https://www.nvidia.com/en-us/design-visualization/solutions/quadro-vr/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/quadro-display-desktop-management/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/rendering',
#  'https://www.nvidia.com/en-eu/design-visualization/omniverse/',
#  'https://www.nvidia.com/en-us/design-visualization/quadro-vdws/',
#  'https://www.nvidia.com/en-eu/design-visualization/solutions/engineering-simulation/',
#  '#nav-lvl1-tab4-lvl2-tab2',
#  'https://www.nvidia.com/en-eu/industries/finance/',
#  'https://www.nvidia.com/en-eu/industries/consumer-internet/',
#  'https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/higher-education-research/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/training',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting',
#  'https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/ai-data-science/ai-workflows',
#  'https://developer.nvidia.com/nvidia-omniverse-platform/ace/tokkio-showcase',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/apache-spark-3',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench',
#  'https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://www.nvidia.com/en-eu/gpu-cloud',
#  'https://catalog.ngc.nvidia.com/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/products/titan-rtx/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/',
#  'https://www.nvidia.com/en-eu/data-center/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/ai-data-science/professional-services/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://resources.nvidia.com/l/en-us-data-science',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://developer.nvidia.com/blog/category/data-science/',
#  'https://www.nvidia.com/en-eu/ai-data-science/kaggle-grandmasters/',
#  '#nav-lvl1-tab4-lvl2-tab3',
#  'https://developer.nvidia.com/join',
#  'https://ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://news.developer.nvidia.com/',
#  'https://developer.nvidia.com/blog',
#  'https://forums.developer.nvidia.com/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-us/gtc/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://developer.nvidia.com/',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://developer.nvidia.com/drive',
#  'https://developer.nvidia.com/MAXINE',
#  'https://developer.nvidia.com/culitho',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/morpheus',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids',
#  'https://developer.nvidia.com/generative-ai',
#  'https://www.nvidia.com/en-eu/clara',
#  'https://developer.nvidia.com/hpc-sdk',
#  'https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/cuopt',
#  'https://developer.nvidia.com/nvidia-omniverse-platform',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://developer.nvidia.com/isaac',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva',
#  'https://developer.nvidia.com/aerial-sdk',
#  'https://developer.nvidia.com/cuda-zone',
#  'https://developer.nvidia.com/embedded/jetpack',
#  'https://developer.nvidia.com/networking/doca',
#  'https://developer.nvidia.com/gpu-accelerated-libraries',
#  'https://developer.nvidia.com/tensorrt',
#  'https://developer.nvidia.com/cudnn',
#  'https://developer.nvidia.com/deep-learning-frameworks',
#  'https://developer.nvidia.com/nvidia-nemo',
#  'https://developer.nvidia.com/deepstream-sdk',
#  'https://developer.nvidia.com/unrealengine',
#  'https://developer.nvidia.com/rtx',
#  'https://developer.nvidia.com/nvidia-video-codec-sdk',
#  'https://developer.nvidia.com/drive/driveworks',
#  'https://www.nvidia.com/en-eu/executive-insights/',
#  '#nav-lvl1-tab4-lvl2-tab5',
#  'https://www.nvidia.com/en-me/geforce/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-me/geforce/gaming-laptops/',
#  'https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/',
#  'https://www.nvidia.com/en-me/geforce/20-series/rtx/',
#  'https://www.nvidia.com/en-me/geforce/geforce-experience/',
#  'https://www.nvidia.com/en-us/geforce/drivers/',
#  'https://www.nvidia.com/en-us/geforce/forums/discover/',
#  'https://www.nvidia.com/en-us/geforce/support/',
#  'https://www.nvidia.com/en-me/geforce/buy/',
#  'https://www.nvidia.com/en-eu/geforce-now/',
#  'https://www.nvidia.com/en-eu/geforce-now/download/',
#  'https://www.nvidia.com/en-eu/geforce-now/games/',
#  'https://www.nvidia.com/en-eu/geforce-now/memberships/',
#  'https://www.nvidia.com/en-eu/geforce-now/faq/',
#  'https://forums.geforce.com/default/board/199/geforce-now-for-mac-beta/',
#  'https://www.nvidia.com/en-eu/geforce-now/support/',
#  'https://www.nvidia.com/en-us/shield/',
#  'https://www.nvidia.com/en-us/shield/compare/',
#  'https://shop.nvidia.com/en-us/shield/',
#  'https://nvidia.custhelp.com/app/answers/detail/a_id/4732',
#  'https://nvidia.custhelp.com/app/shield/st/5/p/178/page/1/',
#  'https://www.nvidia.com/en-us/programs/isv/',
#  '#nav-lvl1-tab4-lvl2-tab7',
#  'https://www.nvidia.com/en-us/deep-learning-ai/solutions/on-premises/',
#  'https://www.nvidia.com/en-eu/data-center/edge-computing/',
#  'https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-eu/networking/',
#  'https://www.nvidia.com/en-eu/data-center/virtualization/',
#  'https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/',
#  'https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/',
#  'https://developer.nvidia.com/egx-stack',
#  'https://developer.nvidia.com/cluster-management',
#  'https://www.nvidia.com/en-eu/data-center/products/fleet-command/',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server',
#  'https://www.nvidia.com/en-eu/data-center/magnum-io/',
#  'https://www.nvidia.com/en-eu/networking/products/software/',
#  'https://www.nvidia.com/en-eu/data-center/virtual-solutions/',
#  'https://www.nvidia.com/en-us/data-center/software/',
#  'https://developer.nvidia.com/dcgm',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/',
#  'https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/',
#  'https://www.nvidia.com/en-eu/data-center/resources/',
#  'https://academy.nvidia.com/en/',
#  'https://www.nvidia.com/en-eu/support/enterprise/',
#  'https://www.nvidia.com/Download/index.aspx?lang=en-us',
#  'https://www.nvidia.com/en-eu/security/',
#  'https://docs.nvidia.com/',
#  'https://forums.developer.nvidia.com/',
#  '#nav-lvl1-tab4-lvl2-tab8',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://www.nvidia.com/en-us/research/research-areas/',
#  'https://www.nvidia.com/en-eu/research/ai-playground/',
#  'https://www.youtube.com/user/NVIDIADeveloper',
#  'https://developer.nvidia.com/research/covid-19',
#  'https://ngc.nvidia.com/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://www.nvidia.com/en-us/research/news/',
#  'https://developer.nvidia.com/blog/',
#  'https://developer.nvidia.com/open-source/',
#  'https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/cambridge-1/',
#  '#nav-lvl1-tab4-lvl2-tab9',
#  'https://www.nvidia.com/en-eu/data-center/dgx-systems/',
#  'https://www.nvidia.com/en-eu/data-center/products/egx/',
#  'https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/jetson-xavier-nx/',
#  'https://developer.nvidia.com/isaac-ros',
#  'https://developer.nvidia.com/isaac-sim',
#  'https://developer.nvidia.com/transfer-learning-toolkit',
#  'https://developer.nvidia.com/deepstream-sdk',
#  'https://www.nvidia.com/en-eu/data-center/products/fleet-command/',
#  'https://developer.nvidia.com/nvidia-omniverse-platform/replicator',
#  'https://www.nvidia.com/en-eu/industries/healthcare/',
#  'https://www.nvidia.com/en-eu/industries/manufacturing/',
#  'https://www.nvidia.com/en-eu/industries/public-sector/',
#  'https://www.nvidia.com/en-eu/industries/retail/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics/',
#  'https://www.nvidia.com/en-eu/industries/',
#  'https://blogs.nvidia.com/blog/category/robotics/',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://developer.nvidia.com/blog?r=1&tags=&categories=robotics',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/startups/',
#  'https://shop.nvidia.com/en-us/',
#  'https://www.nvidia.com/Download/index.aspx?lang=en-us',
#  'https://www.nvidia.com/en-eu/support/',
#  'http://www.enable-javascript.com/',
#  'https://www.nvidia.com/gtc/',
#  'https://blogs.nvidia.com/blog/aws-reinvent-2024/',
#  'https://www.nvidia.com/en-us/events/supercomputing/',
#  'https://build.nvidia.com/nvidia/digital-twins-for-fluid-simulation',
#  'https://nvidianews.nvidia.com/news/nvidia-opens-bionemo-to-scale-digital-biology-for-global-biopharma-and-scientific-industry',
#  'https://nvidianews.nvidia.com/news/nvidia-supercharges-google-quantum-processor-design-with-simulation-of-quantum-device-physics',
#  'https://www.nvidia.com/gtc/?nvid=nv-int-bnr-550763',
#  'https://www.nvidia.com/en-eu/ai/',
#  'https://www.nvidia.com/en-eu/ai-data-science/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting/',
#  'https://developer.nvidia.com/nvidia-merlin',
#  'https://www.nvidia.com/en-eu/ai-data-science/products/riva/',
#  'https://www.nvidia.com/en-gb/deep-learning-ai/solutions/data-science/apache-spark-3/',
#  'https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids/',
#  'https://blogs.nvidia.com/blog/aws-reinvent-2024/',
#  'https://blogs.nvidia.com/blog/aws-reinvent-2024/',
#  'https://developer.nvidia.com/blog/create-a-custom-slackbot-llm-agent-with-nvidia-nim-and-langchain/',
#  'https://developer.nvidia.com/blog/create-a-custom-slackbot-llm-agent-with-nvidia-nim-and-langchain/',
#  'https://developer.nvidia.com/blog/ai-ran-goes-live-and-unlocks-a-new-ai-opportunity-for-telcos/',
#  'https://developer.nvidia.com/blog/ai-ran-goes-live-and-unlocks-a-new-ai-opportunity-for-telcos/',
#  'https://blogs.nvidia.com/blog/japan-sovereign-ai-healthcare/',
#  'https://blogs.nvidia.com/blog/japan-sovereign-ai-healthcare/',
#  'https://blogs.nvidia.com/blog/ai-studio-comfyui-adobe-firefly-photoshop',
#  'https://blogs.nvidia.com/blog/ai-studio-comfyui-adobe-firefly-photoshop',
#  'https://blogs.nvidia.com/blog/nim-agent-blueprints',
#  'https://blogs.nvidia.com/blog/nim-agent-blueprints',
#  'https://blogs.nvidia.com/blog/nvidia-nim-agent-blueprint-virtual-screening/',
#  'https://blogs.nvidia.com/blog/nvidia-nim-agent-blueprint-virtual-screening/',
#  'https://blogs.nvidia.com/blog/ai-decoded-microsoft-ignite-rtx/',
#  'https://blogs.nvidia.com/blog/ai-decoded-microsoft-ignite-rtx/',
#  'https://blogs.nvidia.com/blog/generative-physical-ai-nim-microservices/',
#  'https://blogs.nvidia.com/blog/generative-physical-ai-nim-microservices/',
#  'https://www.nvidia.com/en-gb/design-visualization/where-to-buy/',
#  'https://blogs.nvidia.com/blog/category/pro-graphics/',
#  'https://www.nvidia.com/en-gb/design-visualization/',
#  'https://www.nvidia.com/en-gb/omniverse/',
#  'https://developer.nvidia.com/rtx',
#  'https://www.nvidia.com/en-us/research/',
#  'https://www.nvidia.com/en-gb/design-visualization/solutions/cloud-xr/',
#  'https://blogs.nvidia.com/blog/microsoft-ignite-blackwell-omniverse-rtx-ai',
#  'https://blogs.nvidia.com/blog/microsoft-ignite-blackwell-omniverse-rtx-ai',
#  'https://blogs.nvidia.com/blog/foxconn-blackwell-omniverse/',
#  'https://blogs.nvidia.com/blog/foxconn-blackwell-omniverse/',
#  'https://www.nvidia.com/en-us/learn/learning-path/openusd/',
#  'https://www.nvidia.com/en-us/learn/learning-path/openusd/',
#  'https://blogs.nvidia.com/blog/synctwin-digital-twins-generative-ai-openusd/',
#  'https://blogs.nvidia.com/blog/synctwin-digital-twins-generative-ai-openusd/',
#  'https://blogs.nvidia.com/blog/foxconn-digital-twin-ai',
#  'https://blogs.nvidia.com/blog/foxconn-digital-twin-ai',
#  'https://blogs.nvidia.com/blog/siemens-unlocks-future-of-manufacturing-with-openusd/',
#  'https://blogs.nvidia.com/blog/siemens-unlocks-future-of-manufacturing-with-openusd/',
#  'https://blogs.nvidia.com/blog/ai-digital-twins-industrial-automation-demo',
#  'https://blogs.nvidia.com/blog/ai-digital-twins-industrial-automation-demo',
#  'https://blogs.nvidia.com/blog/siemens-immersive-visualization-generative-ai/',
#  'https://blogs.nvidia.com/blog/siemens-immersive-visualization-generative-ai/',
#  'https://blogs.nvidia.com/blog/generative-ai-openusd-fuels-3d-product-configurators/?nvid=nv-int-csfg-238654',
#  'https://blogs.nvidia.com/blog/generative-ai-openusd-fuels-3d-product-configurators/?nvid=nv-int-csfg-238654',
#  'https://blogs.nvidia.com/blog/omniverse-next-gen-data-center/',
#  'https://blogs.nvidia.com/blog/omniverse-next-gen-data-center/',
#  'https://www.nvidia.com/en-gb/high-performance-computing/',
#  'https://www.nvidia.com/en-us/events/supercomputing/',
#  'https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook/',
#  'https://www.nvidia.com/en-gb/industries/healthcare-life-sciences/',
#  'https://www.nvidia.com/en-gb/industries/public-sector/',
#  'https://www.nvidia.com/en-gb/industries/energy/',
#  'https://developer.nvidia.com/hpc-sdk',
#  'https://developer.nvidia.com/modulus',
#  'https://blogs.nvidia.com/blog/earth-2-nim-simulations/',
#  'https://blogs.nvidia.com/blog/earth-2-nim-simulations/',
#  'https://blogs.nvidia.com/blog/alchemi-nim',
#  'https://blogs.nvidia.com/blog/alchemi-nim',
#  'https://nvidianews.nvidia.com/news/nvidia-accelerates-quantum-computing-centers-worldwide-with-cuda-q-platform',
#  'https://nvidianews.nvidia.com/news/nvidia-accelerates-quantum-computing-centers-worldwide-with-cuda-q-platform',
#  'https://blogs.nvidia.com/blog/national-ai-research-resource-pilot/',
#  'https://blogs.nvidia.com/blog/national-ai-research-resource-pilot/',
#  'https://nvidianews.nvidia.com/news/nvidia-announces-new-system-for-accelerated-quantum-classical-computing',
#  'https://nvidianews.nvidia.com/news/nvidia-announces-new-system-for-accelerated-quantum-classical-computing',
#  'https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook',
#  'https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook',
#  'https://blogs.nvidia.com/blog/2022/11/14/hpc-at-the-edge/',
#  'https://blogs.nvidia.com/blog/2022/11/14/hpc-at-the-edge/',
#  'https://blogs.nvidia.com/blog/2022/11/14/omniverse-digital-twin-data-center/',
#  'https://blogs.nvidia.com/blog/2022/11/14/omniverse-digital-twin-data-center/',
#  'https://www.nvidia.com/en-me/geforce/graphics-cards/',
#  'https://www.nvidia.com/en-me/geforce/gaming-laptops/',
#  'https://www.nvidia.com/en-me/geforce/technologies/dlss/',
#  'https://www.nvidia.com/en-me/geforce/technologies/reflex/',
#  'https://www.nvidia.com/en-me/studio/',
#  'https://www.nvidia.com/en-gb/geforce-now/',
#  'https://www.nvidia.com/en-me/software/nvidia-app/',
#  'https://www.nvidia.com/en-gb/geforce/game-ready-drivers/',
#  'https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/',
#  'https://www.nvidia.com/en-me/geforce/pc-gaming-deals/',
#  'https://www.nvidia.com/en-me/geforce/pc-gaming-deals/',
#  'https://www.nvidia.com/en-eu/geforce/news/dlss-3-ray-tracing-indiana-jones-and-the-great-circle/',
#  'https://www.nvidia.com/en-eu/geforce/news/dlss-3-ray-tracing-indiana-jones-and-the-great-circle/',
#  'https://www.nvidia.com/en-eu/geforce/news/reflex-low-latency-apex-legends-valorant-fortnite-cs2/',
#  'https://www.nvidia.com/en-eu/geforce/news/reflex-low-latency-apex-legends-valorant-fortnite-cs2/',
#  'https://www.nvidia.com/en-eu/software/nvidia-app/',
#  'https://www.nvidia.com/en-eu/software/nvidia-app/',
#  'https://www.nvidia.com/en-eu/geforce/news/mecha-break-nvidia-ace-nims-rtx-pc-laptop-games-apps/',
#  'https://www.nvidia.com/en-eu/geforce/news/mecha-break-nvidia-ace-nims-rtx-pc-laptop-games-apps/',
#  'https://www.nvidia.com/en-me/geforce/campaigns/star-wars-outlaws-bundle/',
#  'https://www.nvidia.com/en-me/geforce/campaigns/star-wars-outlaws-bundle/',
#  'https://www.nvidia.com/en-me/studio/',
#  'https://www.nvidia.com/en-me/studio/',
#  'https://www.nvidia.com/en-gb/geforce-now/games/',
#  'https://www.nvidia.com/en-gb/geforce-now/games/',
#  'https://www.nvidia.com/en-eu/industries/automotive/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/infrastructure/',
#  'https://blogs.nvidia.com/blog/tag/av-podcast/',
#  'https://www.nvidia.com/en-eu/self-driving-cars/drive-videos/',
#  'https://blogs.nvidia.com/blog/volvo-cars-accelerated-computing-ai/',
#  'https://blogs.nvidia.com/blog/volvo-cars-accelerated-computing-ai/',
#  'https://blogs.nvidia.com/blog/auto-research-cvpr-2024',
#  'https://blogs.nvidia.com/blog/auto-research-cvpr-2024',
#  'https://blogs.nvidia.com/blog/foxconn-nvidia-electric-vehicle/',
#  'https://blogs.nvidia.com/blog/foxconn-nvidia-electric-vehicle/',
#  'https://nvidianews.nvidia.com/news/nvidia-drive-powers-next-generation-transportation',
#  'https://nvidianews.nvidia.com/news/nvidia-drive-powers-next-generation-transportation',
#  'https://blogs.nvidia.com/blog/omniverse-cloud-apis/',
#  'https://blogs.nvidia.com/blog/omniverse-cloud-apis/',
#  'https://blogs.nvidia.com/blog/automotive-tech-gtc-2024/',
#  'https://blogs.nvidia.com/blog/automotive-tech-gtc-2024/',
#  'https://blogs.nvidia.com/blog/generative-ai-in-vehicle-experiences/',
#  'https://blogs.nvidia.com/blog/generative-ai-in-vehicle-experiences/',
#  'https://blogs.nvidia.com/blog/omniverse-global-automotive-configurator-developer-ecosystem/',
#  'https://blogs.nvidia.com/blog/omniverse-global-automotive-configurator-developer-ecosystem/',
#  'https://blogs.nvidia.com/blog/2023/03/21/nvidia-ai-and-omniverse-transform-automakers-workflows',
#  'https://blogs.nvidia.com/blog/2023/03/21/nvidia-ai-and-omniverse-transform-automakers-workflows',
#  'https://blogs.nvidia.com/blog/2023/1/3/mercedes-benz-next-gen-factories-omniverse/',
#  'https://blogs.nvidia.com/blog/2023/1/3/mercedes-benz-next-gen-factories-omniverse/',
#  'https://www.nvidia.com/en-gb/edge-computing',
#  'https://developer.nvidia.com/isaac',
#  'https://www.nvidia.com/en-gb/autonomous-machines/',
#  'https://www.nvidia.com/en-us/research/robotics/',
#  'https://www.nvidia.com/en-gb/autonomous-machines/',
#  'https://www.nvidia.com/en-gb/edge-computing/products/igx/',
#  'https://www.nvidia.com/en-gb/data-center/products/certified-systems/',
#  'https://developer.nvidia.com/embedded/ecosystem',
#  'https://developer.nvidia.com/blog/closing-the-sim-to-real-gap-training-spot-quadruped-locomotion-with-nvidia-isaac-lab/',
#  'https://developer.nvidia.com/blog/closing-the-sim-to-real-gap-training-spot-quadruped-locomotion-with-nvidia-isaac-lab/',
#  'https://developer.nvidia.com/blog/supercharge-robotics-workflows-with-ai-and-simulation-using-nvidia-isaac-sim-4-0-and-nvidia-isaac-lab/',
#  'https://developer.nvidia.com/blog/supercharge-robotics-workflows-with-ai-and-simulation-using-nvidia-isaac-sim-4-0-and-nvidia-isaac-lab/',
#  'https://nvidianews.nvidia.com/news/robotic-factories-industrial-digitalization-electronic-makers-ai-omniverse',
#  'https://nvidianews.nvidia.com/news/robotic-factories-industrial-digitalization-electronic-makers-ai-omniverse',
#  'https://nvidianews.nvidia.com/news/real-time-healthcare-industrial-scientific-ai-applications-igx-holoscan',
#  'https://nvidianews.nvidia.com/news/real-time-healthcare-industrial-scientific-ai-applications-igx-holoscan',
#  'https://blogs.nvidia.com/blog/computex-metropolis-nim/',
#  'https://blogs.nvidia.com/blog/computex-metropolis-nim/',
#  'https://blogs.nvidia.com/blog/alphabet-intrinsic-robotics-isaac-manipulator',
#  'https://blogs.nvidia.com/blog/alphabet-intrinsic-robotics-isaac-manipulator',
#  'https://blogs.nvidia.com/blog/isaac-generative-ai-manufacturing-logistics/',
#  'https://blogs.nvidia.com/blog/isaac-generative-ai-manufacturing-logistics/',
#  'https://developer.nvidia.com/blog/scale-ai-enabled-robotics-development-workloads-with-nvidia-osmo/',
#  'https://developer.nvidia.com/blog/scale-ai-enabled-robotics-development-workloads-with-nvidia-osmo/',
#  'https://blogs.nvidia.com/blog/johnson-and-johnson-medtech-ai-surgery/',
#  'https://blogs.nvidia.com/blog/johnson-and-johnson-medtech-ai-surgery/',
#  'https://developer.nvidia.com/blog/step-into-the-future-of-industrial-grade-edge-ai-with-nvidia-jetson-agx-orin-industrial/',
#  'https://developer.nvidia.com/blog/step-into-the-future-of-industrial-grade-edge-ai-with-nvidia-jetson-agx-orin-industrial/',
#  'https://www.nvidia.com/en-gb/data-center/',
#  'https://www.nvidia.com/en-gb/data-center/gpu-cloud-computing/',
#  'https://www.nvidia.com/en-gb/edge-computing/',
#  'https://www.nvidia.com/en-gb/launchpad/',
#  'https://www.nvidia.com/en-gb/data-center/products/ai-enterprise/',
#  'https://www.nvidia.com/en-gb/data-center/dgx-systems/',
#  'https://www.nvidia.com/en-gb/data-center/products/certified-systems/',
#  'https://blogs.nvidia.com/blog/mlperf-training-blackwell',
#  'https://blogs.nvidia.com/blog/mlperf-training-blackwell',
#  'https://blogs.nvidia.com/blog/hugging-face-inference-nim-microservices-dgx-cloud/',
#  'https://blogs.nvidia.com/blog/hugging-face-inference-nim-microservices-dgx-cloud/',
#  'https://www.nvidia.com/en-us/events/microsoft-build/',
#  'https://www.nvidia.com/en-us/events/microsoft-build/',
#  'https://nvidianews.nvidia.com/news/nvidia-grace-hopper-ignites-new-era-of-ai-supercomputing',
#  'https://nvidianews.nvidia.com/news/nvidia-grace-hopper-ignites-new-era-of-ai-supercomputing',
#  'https://blogs.nvidia.com/blog/blackwell-scientific-computing',
#  'https://blogs.nvidia.com/blog/blackwell-scientific-computing',
#  'https://blogs.nvidia.com/blog/tensorrt-llm-inference-mlperf/',
#  'https://blogs.nvidia.com/blog/tensorrt-llm-inference-mlperf/',
#  'https://nvidianews.nvidia.com/news/networking-switches-gpu-computing-ai',
#  'https://nvidianews.nvidia.com/news/networking-switches-gpu-computing-ai',
#  'https://developer.nvidia.com/blog/nvidia-gb200-nvl72-delivers-trillion-parameter-llm-training-and-real-time-inference/',
#  'https://developer.nvidia.com/blog/nvidia-gb200-nvl72-delivers-trillion-parameter-llm-training-and-real-time-inference/',
#  'https://www.nvidia.com/en-us/data-center/dgx-b200/?nvid=nv-int-csfg-733225',
#  'https://www.nvidia.com/en-us/data-center/dgx-b200/?nvid=nv-int-csfg-733225',
#  'https://blogs.nvidia.com/blog/mlperf-inference-benchmark-blackwell/',
#  'https://blogs.nvidia.com/blog/mlperf-inference-benchmark-blackwell/',
#  'https://www.nvidia.com/en-gb/about-nvidia/',
#  'https://www.nvidia.com/gtc',
#  'https://www.nvidia.com/en-gb/about-nvidia/careers/',
#  'https://nvidianews.nvidia.com',
#  'https://www.nvidia.com/en-us/on-demand',
#  'https://nvidianews.nvidia.com/bios',
#  'https://www.nvidia.com/content/dam/en-zz/Solutions/about-nvidia/corporate-nvidia-in-brief.pdf',
#  'https://images.nvidia.com/pdf/NVIDIA-Story.pdf',
#  'https://www.nvidia.com/en-us/events/siggraph/#featured-programs',
#  'https://www.nvidia.com/en-us/events/siggraph/#featured-programs',
#  'https://resources.nvidia.com/gtc24-spring-best-of-highlight',
#  'https://resources.nvidia.com/gtc24-spring-best-of-highlight',
#  'https://www.nvidia.com/en-us/about-nvidia/',
#  'https://www.nvidia.com/en-us/about-nvidia/',
#  'https://blogs.nvidia.com/blog/accelerated-ai-energy-efficiency/',
#  'https://blogs.nvidia.com/blog/accelerated-ai-energy-efficiency/',
#  'https://blogs.nvidia.com/blog/ai-data-science-career-development/',
#  'https://blogs.nvidia.com/blog/ai-data-science-career-development/',
#  'https://blogs.nvidia.com/blog/selin-ornek-robot-guide-dogs/',
#  'https://blogs.nvidia.com/blog/selin-ornek-robot-guide-dogs/',
#  'https://blogs.nvidia.com/blog/nvidia-life-camir-ricketts/',
#  'https://blogs.nvidia.com/blog/nvidia-life-camir-ricketts/',
#  'https://blogs.nvidia.com/blog/te-hiku-media-maori-speech-ai/',
#  'https://blogs.nvidia.com/blog/te-hiku-media-maori-speech-ai/',
#  'https://blogs.nvidia.com/blog/nvidia-life-jennifer-marko/',
#  'https://blogs.nvidia.com/blog/nvidia-life-jennifer-marko/',
#  'https://blogs.nvidia.com/blog/jensen-huang-caltech-commencement-address/',
#  'https://blogs.nvidia.com/blog/jensen-huang-caltech-commencement-address/',
#  'https://www.nvidia.com/en-eu/about-nvidia/',
#  'https://images.nvidia.com/aem-dam/Solutions/homepage/pdf/NVIDIA-Story.pdf',
#  'https://investor.nvidia.com/home/default.aspx',
#  'https://www.nventures.ai',
#  'https://www.nvidia.com/en-eu/foundation/',
#  'https://www.nvidia.com/en-eu/research/',
#  'https://www.nvidia.com/en-eu/csr/',
#  'https://www.nvidia.com/en-eu/technologies/',
#  'https://www.nvidia.com/en-eu/about-nvidia/careers/',
#  'https://nvidianews.nvidia.com/',
#  'https://blogs.nvidia.com/',
#  'https://developer.nvidia.com/blog/',
#  'https://www.nvidia.com/en-eu/about-nvidia/webinar-portal/',
#  'https://www.nvidia.com/en-eu/preferences/email-signup/',
#  'https://www.nvidia.com/en-us/events/',
#  'https://www.nvidia.com/en-us/gtc/?for=emea',
#  'https://www.nvidia.com/en-us/on-demand/',
#  'https://developer.nvidia.com/',
#  'https://www.nvidia.com/en-eu/about-nvidia/partners/',
#  'https://www.nvidia.com/en-eu/executive-insights/',
#  'https://www.nvidia.com/en-eu/startups/',
#  'https://www.nvidia.com/en-us/programs/isv/',
#  'https://docs.nvidia.com/',
#  'https://www.nvidia.com/en-eu/training/',
#  'https://academy.nvidia.com/en/',
#  'https://www.nvidia.com/en-eu/ai-data-science/professional-services/',
#  'https://www.facebook.com/NVIDIAGeForceUK/',
#  'https://www.twitch.tv/nvidia',
#  'https://twitter.com/NVIDIAGeForceUK',
#  'https://www.youtube.com/channel/UCL-g3eGJi1omSDSz48AML-g',
#  'https://www.nvidia.com/en-us/location-selector/',
#  'https://www.nvidia.com/en-eu/about-nvidia/privacy-policy/',
#  'https://www.nvidia.com/en-eu/privacy-center/',
#  'https://www.nvidia.com/en-eu/about-nvidia/terms-of-service/',
#  'https://www.nvidia.com/en-eu/about-nvidia/accessibility/',
#  'https://www.nvidia.com/en-eu/about-nvidia/company-policies/',
#  'https://www.nvidia.com/en-eu/security/',
#  'https://www.nvidia.com/en-eu/contact/']

# %%
link_system_prompt = """
You are provided with a list of links found on a website.
Your task is to decide which links are relevant for a company brochure, such as "About Us" pages, "Careers" pages, etc.
Please return the result in the following JSON format:

{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://full.url/goes/here/careers"},
        {"type": "products page", "url": "https://full.url/goes/here/products"}
    ]
}
"""

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url}. "
    user_prompt += "Please decide which of these links are relevant for a company brochure. "
    user_prompt += "Relevant links may include: About, Company, Careers, Products, Services, etc. "
    user_prompt += "Do not include terms of service, privacy policies, email addresses, or unrelated links. "
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(nvidia))
# Out:
# Here is the list of links on the website of https://www.nvidia.com/en-me/. Please decide which of these links are relevant for a company brochure. Relevant links may include: About, Company, Careers, Products, Services, etc. Do not include terms of service, privacy policies, email addresses, or unrelated links. https://www.nvidia.com
# #page-content
# https://www.nvidia.com/en-me/geforce/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-me/geforce/laptops/
# https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/
# https://www.nvidia.com/en-me/studio/laptops-desktops/
# https://www.nvidia.com/en-eu/shield/
# https://www.nvidia.com/en-me/ai-on-rtx/
# https://www.nvidia.com/en-me/geforce/laptops/
# https://www.nvidia.com/en-eu/design-visualization/desktop-graphics/
# https://www.nvidia.com/en-eu/design-visualization/rtx-professional-laptops/
# https://www.nvidia.com/en-eu/data-center/dgx-station/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-eu/data-center/grace-cpu/
# https://www.nvidia.com/en-eu/data-center/dgx-platform/
# https://www.nvidia.com/en-eu/data-center/products/egx/
# https://www.nvidia.com/en-eu/edge-computing/products/igx/
# https://www.nvidia.com/en-eu/data-center/hgx/
# https://www.nvidia.com/en-eu/data-center/products/mgx/
# https://www.nvidia.com/en-eu/omniverse/platform/ovx/
# https://www.nvidia.com/en-eu/self-driving-cars/simulation/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/networking/products/data-processing-unit/
# https://www.nvidia.com/en-eu/networking/products/ethernet
# https://www.nvidia.com/en-eu/networking/products/infiniband/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-eu/design-visualization/rtx/
# https://www.nvidia.com/en-us/data-center/nvidia-ampere-gpu-architecture/
# https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/
# https://www.nvidia.com/en-eu/self-driving-cars/hardware/
# https://www.nvidia.com/en-eu/clara/medical-devices/
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/self-driving-cars/software
# https://developer.nvidia.com/MAXINE
# https://developer.nvidia.com/culitho
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu//deep-learning-ai/software/rapids
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework
# https://www.nvidia.com/en-eu/clara
# https://developer.nvidia.com/hpc-sdk
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-omniverse-platform
# https://developer.nvidia.com/nvidia-merlin
# https://developer.nvidia.com/isaac-ros
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://developer.nvidia.com/aerial-sdk
# https://www.nvidia.com/en-eu/gpu-accelerated-applications/
# https://catalog.ngc.nvidia.com/
# https://www.nvidia.com/en-eu/gpu-cloud/
# https://www.nvidia.com/en-eu/design-visualization/omniverse/
# https://www.nvidia.com/en-eu/data-center/enterprise-software/
# https://developer.nvidia.com/dcgm
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/
# https://www.nvidia.com/en-eu/studio/software/
# https://www.nvidia.com/en-eu/design-visualization/software/broadcast-app/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench/
# https://www.nvidia.com/en-eu/geforce-now/home
# https://www.nvidia.com/en-me/geforce/geforce-experience/
# https://www.nvidia.com/en-me/geforce/broadcasting/
# https://www.nvidia.com/en-eu/omniverse/apps/machinima/
# https://www.nvidia.com/en-me/geforce/rtx-remix/
# https://www.nvidia.com/en-me/studio/resources/
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/
# https://developer.nvidia.com/egx-stack
# https://developer.nvidia.com/cluster-management
# https://www.nvidia.com/en-eu/data-center/magnum-io/
# https://www.nvidia.com/en-eu/networking/products/software/
# https://www.nvidia.com/en-eu/data-center/virtual-solutions/
# https://www.nvidia.com/en-eu/data-center/base-command
# https://www.nvidia.com/en-eu/clara/bionemo
# https://www.nvidia.com/en-eu/gpu-cloud/nemo-llm-service
# https://www.nvidia.com/en-eu/gpu-cloud/picasso
# https://docs.nvidia.com/ngc/ngc-private-registry-user-guide/index.html
# https://www.nvidia.com/en-eu/omniverse/cloud
# https://www.nvidia.com/en-eu/ai
# https://www.nvidia.com/en-eu/ai-data-science/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai
# https://www.nvidia.com/en-eu/solutions/ai/cybersecurity/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting
# https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/data-center/colocation-partners/
# https://www.nvidia.com/en-eu/data-center/edge-computing/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/data-center/virtualization/
# https://www.nvidia.com/en-eu/data-center/solutions/mlops/
# https://www.nvidia.com/en-eu/solutions/design-and-simulation/
# https://www.nvidia.com/en-eu/omniverse/solutions/digital-twins/
# https://www.nvidia.com/en-eu/design-visualization/
# https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing/
# https://www.nvidia.com/en-eu/self-driving-cars/
# https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics
# https://www.nvidia.com/en-eu/edge-computing
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/high-performance-computing/
# https://www.nvidia.com/en-eu/high-performance-computing/hpc-and-ai/
# https://www.nvidia.com/en-eu/high-performance-computing/scientific-visualization
# https://www.nvidia.com/en-eu/high-performance-computing/simulation-and-modeling
# https://www.nvidia.com/en-eu/solutions/quantum-computing
# https://www.nvidia.com/en-eu/self-driving-cars/
# https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing
# https://www.nvidia.com/en-eu/self-driving-cars/infrastructure
# https://www.nvidia.com/en-eu/industries/
# https://www.nvidia.com/en-eu/industries/aec/
# https://www.nvidia.com/en-eu/industries/automotive/
# https://www.nvidia.com/en-eu/industries/consumer-internet/
# https://www.nvidia.com/en-eu/industries/energy/
# https://www.nvidia.com/en-eu/industries/finance/
# https://www.nvidia.com/en-eu/industries/game-development/
# https://www.nvidia.com/en-eu/industries/global-public-sector/
# https://www.nvidia.com/en-eu/industries/healthcare/
# https://www.nvidia.com/en-eu/industries/higher-education-research/
# https://www.nvidia.com/en-eu/industries/industrial-sector/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/industries/media-and-entertainment/
# https://www.nvidia.com/en-eu/industries/restaurants/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/industries/robotics/
# https://www.nvidia.com/en-eu/industries/smart-cities-and-spaces/
# https://www.nvidia.com/en-eu/industries/supercomputing/
# https://www.nvidia.com/en-eu/industries/telecommunications/
# https://www.nvidia.com/en-eu/industries/public-sector/
# https://www.nvidia.com/en-eu/executive-insights/
# https://www.nvidia.com/en-us/programs/isv/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://www.nvidia.com/en-eu/studio/
# https://www.nvidia.com/en-eu/studio/software/
# https://www.nvidia.com/en-eu/studio/products/
# https://www.nvidia.com/en-eu/studio/compare-gpus/
# https://www.nvidia.com/en-us/studio/shop/
# https://www.nvidia.com/en-us/design-visualization/industries/media-entertainment/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/design-visualization/industries/architecture-engineering-construction/
# https://www.nvidia.com/en-eu/industries
# https://www.nvidia.com/en-us/design-visualization/quadro-servers/rtx/
# https://www.nvidia.com/en-eu/design-visualization/quadro/
# https://www.nvidia.com/en-us/design-visualization/solutions/quadro-vr/
# https://www.nvidia.com/en-eu/design-visualization/solutions/quadro-display-desktop-management/
# https://www.nvidia.com/en-eu/design-visualization/solutions/rendering
# https://www.nvidia.com/en-eu/design-visualization/omniverse/
# https://www.nvidia.com/en-us/design-visualization/quadro-vdws/
# https://www.nvidia.com/en-eu/design-visualization/solutions/engineering-simulation/
# https://www.nvidia.com/en-eu/industries/finance/
# https://www.nvidia.com/en-eu/industries/consumer-internet/
# https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/higher-education-research/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/industries/public-sector/
# https://www.nvidia.com/en-eu/industries/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/training
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting
# https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://developer.nvidia.com/nvidia-omniverse-platform/ace/tokkio-showcase
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/apache-spark-3
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-merlin
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://www.nvidia.com/en-eu/gpu-cloud
# https://catalog.ngc.nvidia.com/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-eu/deep-learning-ai/products/titan-rtx/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/ai-data-science/professional-services/
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://resources.nvidia.com/l/en-us-data-science
# https://www.nvidia.com/en-eu/research/
# https://developer.nvidia.com/blog/category/data-science/
# https://www.nvidia.com/en-eu/ai-data-science/kaggle-grandmasters/
# https://developer.nvidia.com/join
# https://ngc.nvidia.com/
# https://www.nvidia.com/en-eu/training/
# https://news.developer.nvidia.com/
# https://developer.nvidia.com/blog
# https://forums.developer.nvidia.com/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-us/gtc/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://developer.nvidia.com/
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://developer.nvidia.com/drive
# https://developer.nvidia.com/MAXINE
# https://developer.nvidia.com/culitho
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids
# https://developer.nvidia.com/generative-ai
# https://www.nvidia.com/en-eu/clara
# https://developer.nvidia.com/hpc-sdk
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-omniverse-platform
# https://developer.nvidia.com/nvidia-merlin
# https://developer.nvidia.com/isaac
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://developer.nvidia.com/aerial-sdk
# https://developer.nvidia.com/cuda-zone
# https://developer.nvidia.com/embedded/jetpack
# https://developer.nvidia.com/networking/doca
# https://developer.nvidia.com/gpu-accelerated-libraries
# https://developer.nvidia.com/tensorrt
# https://developer.nvidia.com/cudnn
# https://developer.nvidia.com/deep-learning-frameworks
# https://developer.nvidia.com/nvidia-nemo
# https://developer.nvidia.com/deepstream-sdk
# https://developer.nvidia.com/unrealengine
# https://developer.nvidia.com/rtx
# https://developer.nvidia.com/nvidia-video-codec-sdk
# https://developer.nvidia.com/drive/driveworks
# https://www.nvidia.com/en-me/geforce/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-me/geforce/gaming-laptops/
# https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/
# https://www.nvidia.com/en-me/geforce/20-series/rtx/
# https://www.nvidia.com/en-me/geforce/geforce-experience/
# https://www.nvidia.com/en-us/geforce/drivers/
# https://www.nvidia.com/en-us/geforce/forums/discover/
# https://www.nvidia.com/en-us/geforce/support/
# https://www.nvidia.com/en-me/geforce/buy/
# https://www.nvidia.com/en-eu/geforce-now/
# https://www.nvidia.com/en-eu/geforce-now/download/
# https://www.nvidia.com/en-eu/geforce-now/games/
# https://www.nvidia.com/en-eu/geforce-now/memberships/
# https://www.nvidia.com/en-eu/geforce-now/faq/
# https://forums.geforce.com/default/board/199/geforce-now-for-mac-beta/
# https://www.nvidia.com/en-eu/geforce-now/support/
# https://www.nvidia.com/en-us/shield/
# https://www.nvidia.com/en-us/shield/compare/
# https://shop.nvidia.com/en-us/shield/
# https://nvidia.custhelp.com/app/answers/detail/a_id/4732
# https://nvidia.custhelp.com/app/shield/st/5/p/178/page/1/
# https://www.nvidia.com/en-me/geforce/campaigns/back-to-school/?nvid=nv-int-bnr-719151#cid=_nv-int-bnr_en-me
# https://www.nvidia.com/en-us/deep-learning-ai/solutions/on-premises/
# https://www.nvidia.com/en-eu/data-center/edge-computing/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/data-center/virtualization/
# https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/
# https://developer.nvidia.com/egx-stack
# https://developer.nvidia.com/cluster-management
# https://www.nvidia.com/en-eu/data-center/products/fleet-command/
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/data-center/magnum-io/
# https://www.nvidia.com/en-eu/networking/products/software/
# https://www.nvidia.com/en-eu/data-center/virtual-solutions/
# https://www.nvidia.com/en-us/data-center/software/
# https://developer.nvidia.com/dcgm
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/
# https://www.nvidia.com/en-eu/data-center/resources/
# https://academy.nvidia.com/en/
# https://www.nvidia.com/en-eu/support/enterprise/
# https://www.nvidia.com/Download/index.aspx?lang=en-us
# https://www.nvidia.com/en-eu/security/
# https://docs.nvidia.com/
# https://forums.developer.nvidia.com/
# https://www.nvidia.com/en-eu/research/
# https://www.nvidia.com/en-us/research/research-areas/
# https://www.nvidia.com/en-eu/research/ai-playground/
# https://www.youtube.com/user/NVIDIADeveloper
# https://developer.nvidia.com/research/covid-19
# https://ngc.nvidia.com/
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://www.nvidia.com/en-us/research/news/
# https://developer.nvidia.com/blog/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/cambridge-1/
# https://www.nvidia.com/en-eu/data-center/dgx-systems/
# https://www.nvidia.com/en-eu/data-center/products/egx/
# https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/jetson-xavier-nx/
# https://developer.nvidia.com/isaac-ros
# https://developer.nvidia.com/isaac-sim
# https://developer.nvidia.com/transfer-learning-toolkit
# https://developer.nvidia.com/deepstream-sdk
# https://www.nvidia.com/en-eu/data-center/products/fleet-command/
# https://developer.nvidia.com/nvidia-omniverse-platform/replicator
# https://www.nvidia.com/en-eu/industries/healthcare/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/industries/public-sector/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics/
# https://www.nvidia.com/en-eu/industries/
# https://blogs.nvidia.com/blog/category/robotics/
# https://www.nvidia.com/en-eu/research/
# https://developer.nvidia.com/blog?r=1&tags=&categories=robotics
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://shop.nvidia.com/en-us/
# https://www.nvidia.com/Download/index.aspx?lang=en-us
# https://www.nvidia.com/en-eu/support/
# #
# #
# https://www.nvidia.co.uk/account/edit-profile
# #
# #
# #page-content
# #
# #
# https://www.nvidia.com/en-me/geforce/
# /
# https://www.nvidia.co.uk/account/edit-profile
# #
# #
# #nav-lvl1-tab1
# #nav-lvl1-tab1-lvl2-tab1
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-me/geforce/laptops/
# https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/
# https://www.nvidia.com/en-me/studio/laptops-desktops/
# https://www.nvidia.com/en-eu/shield/
# https://www.nvidia.com/en-me/ai-on-rtx/
# https://www.nvidia.com/en-me/geforce/laptops/
# https://www.nvidia.com/en-eu/design-visualization/desktop-graphics/
# https://www.nvidia.com/en-eu/design-visualization/rtx-professional-laptops/
# https://www.nvidia.com/en-eu/data-center/dgx-station/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-eu/data-center/grace-cpu/
# https://www.nvidia.com/en-eu/data-center/dgx-platform/
# https://www.nvidia.com/en-eu/data-center/products/egx/
# https://www.nvidia.com/en-eu/edge-computing/products/igx/
# https://www.nvidia.com/en-eu/data-center/hgx/
# https://www.nvidia.com/en-eu/data-center/products/mgx/
# https://www.nvidia.com/en-eu/omniverse/platform/ovx/
# https://www.nvidia.com/en-eu/self-driving-cars/simulation/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/networking/products/data-processing-unit/
# https://www.nvidia.com/en-eu/networking/products/ethernet
# https://www.nvidia.com/en-eu/networking/products/infiniband/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-eu/design-visualization/rtx/
# https://www.nvidia.com/en-us/data-center/nvidia-ampere-gpu-architecture/
# https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/
# https://www.nvidia.com/en-eu/self-driving-cars/hardware/
# https://www.nvidia.com/en-eu/clara/medical-devices/
# #nav-lvl1-tab1-lvl2-tab2
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/self-driving-cars/software
# https://developer.nvidia.com/MAXINE
# https://developer.nvidia.com/culitho
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu//deep-learning-ai/software/rapids
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework
# https://www.nvidia.com/en-eu/clara
# https://developer.nvidia.com/hpc-sdk
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-omniverse-platform
# https://developer.nvidia.com/nvidia-merlin
# https://developer.nvidia.com/isaac-ros
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://developer.nvidia.com/aerial-sdk
# https://www.nvidia.com/en-eu/gpu-accelerated-applications/
# https://catalog.ngc.nvidia.com/
# https://www.nvidia.com/en-eu/gpu-cloud/
# https://www.nvidia.com/en-eu/design-visualization/omniverse/
# https://www.nvidia.com/en-eu/data-center/enterprise-software/
# https://developer.nvidia.com/dcgm
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/
# https://www.nvidia.com/en-eu/studio/software/
# https://www.nvidia.com/en-eu/design-visualization/software/broadcast-app/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench/
# https://www.nvidia.com/en-eu/geforce-now/home
# https://www.nvidia.com/en-me/geforce/geforce-experience/
# https://www.nvidia.com/en-me/geforce/broadcasting/
# https://www.nvidia.com/en-eu/omniverse/apps/machinima/
# https://www.nvidia.com/en-me/geforce/rtx-remix/
# https://www.nvidia.com/en-me/studio/resources/
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/
# https://developer.nvidia.com/egx-stack
# https://developer.nvidia.com/cluster-management
# https://www.nvidia.com/en-eu/data-center/magnum-io/
# https://www.nvidia.com/en-eu/networking/products/software/
# https://www.nvidia.com/en-eu/data-center/virtual-solutions/
# https://www.nvidia.com/en-eu/data-center/base-command
# https://www.nvidia.com/en-eu/clara/bionemo
# https://www.nvidia.com/en-eu/gpu-cloud/nemo-llm-service
# https://www.nvidia.com/en-eu/gpu-cloud/picasso
# https://docs.nvidia.com/ngc/ngc-private-registry-user-guide/index.html
# https://www.nvidia.com/en-eu/omniverse/cloud
# #nav-lvl1-tab2
# https://www.nvidia.com/en-eu/ai
# https://www.nvidia.com/en-eu/ai-data-science/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai
# https://www.nvidia.com/en-eu/solutions/ai/cybersecurity/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting
# https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/data-center/colocation-partners/
# https://www.nvidia.com/en-eu/data-center/edge-computing/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/data-center/virtualization/
# https://www.nvidia.com/en-eu/data-center/solutions/mlops/
# https://www.nvidia.com/en-eu/solutions/design-and-simulation/
# https://www.nvidia.com/en-eu/omniverse/solutions/digital-twins/
# https://www.nvidia.com/en-eu/design-visualization/
# https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing/
# https://www.nvidia.com/en-eu/self-driving-cars/
# https://www.nvidia.com/en-eu/solutions/robotics-and-edge-computing
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics
# https://www.nvidia.com/en-eu/edge-computing
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/high-performance-computing/
# https://www.nvidia.com/en-eu/high-performance-computing/hpc-and-ai/
# https://www.nvidia.com/en-eu/high-performance-computing/scientific-visualization
# https://www.nvidia.com/en-eu/high-performance-computing/simulation-and-modeling
# https://www.nvidia.com/en-eu/solutions/quantum-computing
# https://www.nvidia.com/en-eu/self-driving-cars/
# https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing
# https://www.nvidia.com/en-eu/self-driving-cars/infrastructure
# #nav-lvl1-tab3
# https://www.nvidia.com/en-eu/industries/
# https://www.nvidia.com/en-eu/industries/aec/
# https://www.nvidia.com/en-eu/industries/automotive/
# https://www.nvidia.com/en-eu/industries/consumer-internet/
# https://www.nvidia.com/en-eu/industries/energy/
# https://www.nvidia.com/en-eu/industries/finance/
# https://www.nvidia.com/en-eu/industries/game-development/
# https://www.nvidia.com/en-eu/industries/global-public-sector/
# https://www.nvidia.com/en-eu/industries/healthcare/
# https://www.nvidia.com/en-eu/industries/higher-education-research/
# https://www.nvidia.com/en-eu/industries/industrial-sector/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/industries/media-and-entertainment/
# https://www.nvidia.com/en-eu/industries/restaurants/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/industries/robotics/
# https://www.nvidia.com/en-eu/industries/smart-cities-and-spaces/
# https://www.nvidia.com/en-eu/industries/supercomputing/
# https://www.nvidia.com/en-eu/industries/telecommunications/
# https://www.nvidia.com/en-eu/industries/public-sector/
# #nav-lvl1-tab4
# #nav-lvl1-tab4-lvl2-tab1
# https://www.nvidia.com/en-eu/studio/
# https://www.nvidia.com/en-eu/studio/software/
# https://www.nvidia.com/en-eu/studio/products/
# https://www.nvidia.com/en-eu/studio/compare-gpus/
# https://www.nvidia.com/en-us/studio/shop/
# https://www.nvidia.com/en-us/design-visualization/industries/media-entertainment/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/design-visualization/industries/architecture-engineering-construction/
# https://www.nvidia.com/en-eu/industries
# https://www.nvidia.com/en-us/design-visualization/quadro-servers/rtx/
# https://www.nvidia.com/en-eu/design-visualization/quadro/
# https://www.nvidia.com/en-us/design-visualization/solutions/quadro-vr/
# https://www.nvidia.com/en-eu/design-visualization/solutions/quadro-display-desktop-management/
# https://www.nvidia.com/en-eu/design-visualization/solutions/rendering
# https://www.nvidia.com/en-eu/design-visualization/omniverse/
# https://www.nvidia.com/en-us/design-visualization/quadro-vdws/
# https://www.nvidia.com/en-eu/design-visualization/solutions/engineering-simulation/
# #nav-lvl1-tab4-lvl2-tab2
# https://www.nvidia.com/en-eu/industries/finance/
# https://www.nvidia.com/en-eu/industries/consumer-internet/
# https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/higher-education-research/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/industries/public-sector/
# https://www.nvidia.com/en-eu/industries/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/inference-platform
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/conversational-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/training
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting
# https://www.nvidia.com/en-eu/ai-data-science/solutions/speech-ai
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/ai-data-science/ai-workflows
# https://developer.nvidia.com/nvidia-omniverse-platform/ace/tokkio-showcase
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/apache-spark-3
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workbench
# https://www.nvidia.com/en-eu/ai-data-science/generative-ai/nemo-framework
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-merlin
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://www.nvidia.com/en-eu/gpu-cloud
# https://catalog.ngc.nvidia.com/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-eu/deep-learning-ai/products/titan-rtx/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-science/workstations/
# https://www.nvidia.com/en-eu/data-center/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/ai-data-science/professional-services/
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://resources.nvidia.com/l/en-us-data-science
# https://www.nvidia.com/en-eu/research/
# https://developer.nvidia.com/blog/category/data-science/
# https://www.nvidia.com/en-eu/ai-data-science/kaggle-grandmasters/
# #nav-lvl1-tab4-lvl2-tab3
# https://developer.nvidia.com/join
# https://ngc.nvidia.com/
# https://www.nvidia.com/en-eu/training/
# https://news.developer.nvidia.com/
# https://developer.nvidia.com/blog
# https://forums.developer.nvidia.com/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-us/gtc/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://developer.nvidia.com/
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://developer.nvidia.com/drive
# https://developer.nvidia.com/MAXINE
# https://developer.nvidia.com/culitho
# https://www.nvidia.com/en-eu/ai-data-science/products/morpheus
# https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids
# https://developer.nvidia.com/generative-ai
# https://www.nvidia.com/en-eu/clara
# https://developer.nvidia.com/hpc-sdk
# https://www.nvidia.com/en-eu/autonomous-machines/intelligent-video-analytics-platform
# https://www.nvidia.com/en-eu/ai-data-science/products/cuopt
# https://developer.nvidia.com/nvidia-omniverse-platform
# https://developer.nvidia.com/nvidia-merlin
# https://developer.nvidia.com/isaac
# https://www.nvidia.com/en-eu/ai-data-science/products/riva
# https://developer.nvidia.com/aerial-sdk
# https://developer.nvidia.com/cuda-zone
# https://developer.nvidia.com/embedded/jetpack
# https://developer.nvidia.com/networking/doca
# https://developer.nvidia.com/gpu-accelerated-libraries
# https://developer.nvidia.com/tensorrt
# https://developer.nvidia.com/cudnn
# https://developer.nvidia.com/deep-learning-frameworks
# https://developer.nvidia.com/nvidia-nemo
# https://developer.nvidia.com/deepstream-sdk
# https://developer.nvidia.com/unrealengine
# https://developer.nvidia.com/rtx
# https://developer.nvidia.com/nvidia-video-codec-sdk
# https://developer.nvidia.com/drive/driveworks
# https://www.nvidia.com/en-eu/executive-insights/
# #nav-lvl1-tab4-lvl2-tab5
# https://www.nvidia.com/en-me/geforce/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-me/geforce/gaming-laptops/
# https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/
# https://www.nvidia.com/en-me/geforce/20-series/rtx/
# https://www.nvidia.com/en-me/geforce/geforce-experience/
# https://www.nvidia.com/en-us/geforce/drivers/
# https://www.nvidia.com/en-us/geforce/forums/discover/
# https://www.nvidia.com/en-us/geforce/support/
# https://www.nvidia.com/en-me/geforce/buy/
# https://www.nvidia.com/en-eu/geforce-now/
# https://www.nvidia.com/en-eu/geforce-now/download/
# https://www.nvidia.com/en-eu/geforce-now/games/
# https://www.nvidia.com/en-eu/geforce-now/memberships/
# https://www.nvidia.com/en-eu/geforce-now/faq/
# https://forums.geforce.com/default/board/199/geforce-now-for-mac-beta/
# https://www.nvidia.com/en-eu/geforce-now/support/
# https://www.nvidia.com/en-us/shield/
# https://www.nvidia.com/en-us/shield/compare/
# https://shop.nvidia.com/en-us/shield/
# https://nvidia.custhelp.com/app/answers/detail/a_id/4732
# https://nvidia.custhelp.com/app/shield/st/5/p/178/page/1/
# https://www.nvidia.com/en-us/programs/isv/
# #nav-lvl1-tab4-lvl2-tab7
# https://www.nvidia.com/en-us/deep-learning-ai/solutions/on-premises/
# https://www.nvidia.com/en-eu/data-center/edge-computing/
# https://www.nvidia.com/en-eu/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-eu/networking/
# https://www.nvidia.com/en-eu/data-center/virtualization/
# https://www.nvidia.com/en-us/data-center/accelerated-computing-for-enterprise-it/
# https://www.nvidia.com/en-eu/data-center/products/ai-enterprise-suite/
# https://developer.nvidia.com/egx-stack
# https://developer.nvidia.com/cluster-management
# https://www.nvidia.com/en-eu/data-center/products/fleet-command/
# https://www.nvidia.com/en-eu/ai-data-science/products/triton-inference-server
# https://www.nvidia.com/en-eu/data-center/magnum-io/
# https://www.nvidia.com/en-eu/networking/products/software/
# https://www.nvidia.com/en-eu/data-center/virtual-solutions/
# https://www.nvidia.com/en-us/data-center/software/
# https://developer.nvidia.com/dcgm
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-experience/
# https://www.nvidia.com/en-eu/design-visualization/software/rtx-desktop-manager/
# https://www.nvidia.com/en-eu/data-center/resources/
# https://academy.nvidia.com/en/
# https://www.nvidia.com/en-eu/support/enterprise/
# https://www.nvidia.com/Download/index.aspx?lang=en-us
# https://www.nvidia.com/en-eu/security/
# https://docs.nvidia.com/
# https://forums.developer.nvidia.com/
# #nav-lvl1-tab4-lvl2-tab8
# https://www.nvidia.com/en-eu/research/
# https://www.nvidia.com/en-us/research/research-areas/
# https://www.nvidia.com/en-eu/research/ai-playground/
# https://www.youtube.com/user/NVIDIADeveloper
# https://developer.nvidia.com/research/covid-19
# https://ngc.nvidia.com/
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://www.nvidia.com/en-us/research/news/
# https://developer.nvidia.com/blog/
# https://developer.nvidia.com/open-source/
# https://www.nvidia.com/en-eu/industries/healthcare-life-sciences/cambridge-1/
# #nav-lvl1-tab4-lvl2-tab9
# https://www.nvidia.com/en-eu/data-center/dgx-systems/
# https://www.nvidia.com/en-eu/data-center/products/egx/
# https://www.nvidia.com/en-eu/autonomous-machines/embedded-systems/jetson-xavier-nx/
# https://developer.nvidia.com/isaac-ros
# https://developer.nvidia.com/isaac-sim
# https://developer.nvidia.com/transfer-learning-toolkit
# https://developer.nvidia.com/deepstream-sdk
# https://www.nvidia.com/en-eu/data-center/products/fleet-command/
# https://developer.nvidia.com/nvidia-omniverse-platform/replicator
# https://www.nvidia.com/en-eu/industries/healthcare/
# https://www.nvidia.com/en-eu/industries/manufacturing/
# https://www.nvidia.com/en-eu/industries/public-sector/
# https://www.nvidia.com/en-eu/industries/retail/
# https://www.nvidia.com/en-eu/deep-learning-ai/industries/robotics/
# https://www.nvidia.com/en-eu/industries/
# https://blogs.nvidia.com/blog/category/robotics/
# https://www.nvidia.com/en-eu/research/
# https://developer.nvidia.com/blog?r=1&tags=&categories=robotics
# https://www.nvidia.com/en-eu/training/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://www.nvidia.com/en-eu/deep-learning-ai/startups/
# https://shop.nvidia.com/en-us/
# https://www.nvidia.com/Download/index.aspx?lang=en-us
# https://www.nvidia.com/en-eu/support/
# http://www.enable-javascript.com/
# https://www.nvidia.com/gtc/
# https://blogs.nvidia.com/blog/aws-reinvent-2024/
# https://www.nvidia.com/en-us/events/supercomputing/
# https://build.nvidia.com/nvidia/digital-twins-for-fluid-simulation
# https://nvidianews.nvidia.com/news/nvidia-opens-bionemo-to-scale-digital-biology-for-global-biopharma-and-scientific-industry
# https://nvidianews.nvidia.com/news/nvidia-supercharges-google-quantum-processor-design-with-simulation-of-quantum-device-physics
# https://www.nvidia.com/gtc/?nvid=nv-int-bnr-550763
# https://www.nvidia.com/en-eu/ai/
# https://www.nvidia.com/en-eu/ai-data-science/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/data-analytics/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/machine-learning/
# https://www.nvidia.com/en-eu/deep-learning-ai/solutions/prediction-forecasting/
# https://developer.nvidia.com/nvidia-merlin
# https://www.nvidia.com/en-eu/ai-data-science/products/riva/
# https://www.nvidia.com/en-gb/deep-learning-ai/solutions/data-science/apache-spark-3/
# https://www.nvidia.com/en-eu/deep-learning-ai/software/rapids/
# https://blogs.nvidia.com/blog/aws-reinvent-2024/
# https://blogs.nvidia.com/blog/aws-reinvent-2024/
# https://developer.nvidia.com/blog/create-a-custom-slackbot-llm-agent-with-nvidia-nim-and-langchain/
# https://developer.nvidia.com/blog/create-a-custom-slackbot-llm-agent-with-nvidia-nim-and-langchain/
# https://developer.nvidia.com/blog/ai-ran-goes-live-and-unlocks-a-new-ai-opportunity-for-telcos/
# https://developer.nvidia.com/blog/ai-ran-goes-live-and-unlocks-a-new-ai-opportunity-for-telcos/
# https://blogs.nvidia.com/blog/japan-sovereign-ai-healthcare/
# https://blogs.nvidia.com/blog/japan-sovereign-ai-healthcare/
# https://blogs.nvidia.com/blog/ai-studio-comfyui-adobe-firefly-photoshop
# https://blogs.nvidia.com/blog/ai-studio-comfyui-adobe-firefly-photoshop
# https://blogs.nvidia.com/blog/nim-agent-blueprints
# https://blogs.nvidia.com/blog/nim-agent-blueprints
# https://blogs.nvidia.com/blog/nvidia-nim-agent-blueprint-virtual-screening/
# https://blogs.nvidia.com/blog/nvidia-nim-agent-blueprint-virtual-screening/
# https://blogs.nvidia.com/blog/ai-decoded-microsoft-ignite-rtx/
# https://blogs.nvidia.com/blog/ai-decoded-microsoft-ignite-rtx/
# https://blogs.nvidia.com/blog/generative-physical-ai-nim-microservices/
# https://blogs.nvidia.com/blog/generative-physical-ai-nim-microservices/
# https://www.nvidia.com/en-gb/design-visualization/where-to-buy/
# https://blogs.nvidia.com/blog/category/pro-graphics/
# https://www.nvidia.com/en-gb/design-visualization/
# https://www.nvidia.com/en-gb/omniverse/
# https://developer.nvidia.com/rtx
# https://www.nvidia.com/en-us/research/
# https://www.nvidia.com/en-gb/design-visualization/solutions/cloud-xr/
# https://blogs.nvidia.com/blog/microsoft-ignite-blackwell-omniverse-rtx-ai
# https://blogs.nvidia.com/blog/microsoft-ignite-blackwell-omniverse-rtx-ai
# https://blogs.nvidia.com/blog/foxconn-blackwell-omniverse/
# https://blogs.nvidia.com/blog/foxconn-blackwell-omniverse/
# https://www.nvidia.com/en-us/learn/learning-path/openusd/
# https://www.nvidia.com/en-us/learn/learning-path/openusd/
# https://blogs.nvidia.com/blog/synctwin-digital-twins-generative-ai-openusd/
# https://blogs.nvidia.com/blog/synctwin-digital-twins-generative-ai-openusd/
# https://blogs.nvidia.com/blog/foxconn-digital-twin-ai
# https://blogs.nvidia.com/blog/foxconn-digital-twin-ai
# https://blogs.nvidia.com/blog/siemens-unlocks-future-of-manufacturing-with-openusd/
# https://blogs.nvidia.com/blog/siemens-unlocks-future-of-manufacturing-with-openusd/
# https://blogs.nvidia.com/blog/ai-digital-twins-industrial-automation-demo
# https://blogs.nvidia.com/blog/ai-digital-twins-industrial-automation-demo
# https://blogs.nvidia.com/blog/siemens-immersive-visualization-generative-ai/
# https://blogs.nvidia.com/blog/siemens-immersive-visualization-generative-ai/
# https://blogs.nvidia.com/blog/generative-ai-openusd-fuels-3d-product-configurators/?nvid=nv-int-csfg-238654
# https://blogs.nvidia.com/blog/generative-ai-openusd-fuels-3d-product-configurators/?nvid=nv-int-csfg-238654
# https://blogs.nvidia.com/blog/omniverse-next-gen-data-center/
# https://blogs.nvidia.com/blog/omniverse-next-gen-data-center/
# https://www.nvidia.com/en-gb/high-performance-computing/
# https://www.nvidia.com/en-us/events/supercomputing/
# https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook/
# https://www.nvidia.com/en-gb/industries/healthcare-life-sciences/
# https://www.nvidia.com/en-gb/industries/public-sector/
# https://www.nvidia.com/en-gb/industries/energy/
# https://developer.nvidia.com/hpc-sdk
# https://developer.nvidia.com/modulus
# https://blogs.nvidia.com/blog/earth-2-nim-simulations/
# https://blogs.nvidia.com/blog/earth-2-nim-simulations/
# https://blogs.nvidia.com/blog/alchemi-nim
# https://blogs.nvidia.com/blog/alchemi-nim
# https://nvidianews.nvidia.com/news/nvidia-accelerates-quantum-computing-centers-worldwide-with-cuda-q-platform
# https://nvidianews.nvidia.com/news/nvidia-accelerates-quantum-computing-centers-worldwide-with-cuda-q-platform
# https://blogs.nvidia.com/blog/national-ai-research-resource-pilot/
# https://blogs.nvidia.com/blog/national-ai-research-resource-pilot/
# https://nvidianews.nvidia.com/news/nvidia-announces-new-system-for-accelerated-quantum-classical-computing
# https://nvidianews.nvidia.com/news/nvidia-announces-new-system-for-accelerated-quantum-classical-computing
# https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook
# https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook
# https://blogs.nvidia.com/blog/2022/11/14/hpc-at-the-edge/
# https://blogs.nvidia.com/blog/2022/11/14/hpc-at-the-edge/
# https://blogs.nvidia.com/blog/2022/11/14/omniverse-digital-twin-data-center/
# https://blogs.nvidia.com/blog/2022/11/14/omniverse-digital-twin-data-center/
# https://www.nvidia.com/en-me/geforce/graphics-cards/
# https://www.nvidia.com/en-me/geforce/gaming-laptops/
# https://www.nvidia.com/en-me/geforce/technologies/dlss/
# https://www.nvidia.com/en-me/geforce/technologies/reflex/
# https://www.nvidia.com/en-me/studio/
# https://www.nvidia.com/en-gb/geforce-now/
# https://www.nvidia.com/en-me/software/nvidia-app/
# https://www.nvidia.com/en-gb/geforce/game-ready-drivers/
# https://www.nvidia.com/en-me/geforce/products/g-sync-monitors/
# https://www.nvidia.com/en-me/geforce/pc-gaming-deals/
# https://www.nvidia.com/en-me/geforce/pc-gaming-deals/
# https://www.nvidia.com/en-eu/geforce/news/dlss-3-ray-tracing-indiana-jones-and-the-great-circle/
# https://www.nvidia.com/en-eu/geforce/news/dlss-3-ray-tracing-indiana-jones-and-the-great-circle/
# https://www.nvidia.com/en-eu/geforce/news/reflex-low-latency-apex-legends-valorant-fortnite-cs2/
# https://www.nvidia.com/en-eu/geforce/news/reflex-low-latency-apex-legends-valorant-fortnite-cs2/
# https://www.nvidia.com/en-eu/software/nvidia-app/
# https://www.nvidia.com/en-eu/software/nvidia-app/
# https://www.nvidia.com/en-eu/geforce/news/mecha-break-nvidia-ace-nims-rtx-pc-laptop-games-apps/
# https://www.nvidia.com/en-eu/geforce/news/mecha-break-nvidia-ace-nims-rtx-pc-laptop-games-apps/
# https://www.nvidia.com/en-me/geforce/campaigns/star-wars-outlaws-bundle/
# https://www.nvidia.com/en-me/geforce/campaigns/star-wars-outlaws-bundle/
# https://www.nvidia.com/en-me/studio/
# https://www.nvidia.com/en-me/studio/
# https://www.nvidia.com/en-gb/geforce-now/games/
# https://www.nvidia.com/en-gb/geforce-now/games/
# https://www.nvidia.com/en-eu/industries/automotive/
# https://www.nvidia.com/en-eu/self-driving-cars/
# https://www.nvidia.com/en-eu/self-driving-cars/in-vehicle-computing/
# https://www.nvidia.com/en-eu/self-driving-cars/infrastructure/
# https://blogs.nvidia.com/blog/tag/av-podcast/
# https://www.nvidia.com/en-eu/self-driving-cars/drive-videos/
# https://blogs.nvidia.com/blog/volvo-cars-accelerated-computing-ai/
# https://blogs.nvidia.com/blog/volvo-cars-accelerated-computing-ai/
# https://blogs.nvidia.com/blog/auto-research-cvpr-2024
# https://blogs.nvidia.com/blog/auto-research-cvpr-2024
# https://blogs.nvidia.com/blog/foxconn-nvidia-electric-vehicle/
# https://blogs.nvidia.com/blog/foxconn-nvidia-electric-vehicle/
# https://nvidianews.nvidia.com/news/nvidia-drive-powers-next-generation-transportation
# https://nvidianews.nvidia.com/news/nvidia-drive-powers-next-generation-transportation
# https://blogs.nvidia.com/blog/omniverse-cloud-apis/
# https://blogs.nvidia.com/blog/omniverse-cloud-apis/
# https://blogs.nvidia.com/blog/automotive-tech-gtc-2024/
# https://blogs.nvidia.com/blog/automotive-tech-gtc-2024/
# https://blogs.nvidia.com/blog/generative-ai-in-vehicle-experiences/
# https://blogs.nvidia.com/blog/generative-ai-in-vehicle-experiences/
# https://blogs.nvidia.com/blog/omniverse-global-automotive-configurator-developer-ecosystem/
# https://blogs.nvidia.com/blog/omniverse-global-automotive-configurator-developer-ecosystem/
# https://blogs.nvidia.com/blog/2023/03/21/nvidia-ai-and-omniverse-transform-automakers-workflows
# https://blogs.nvidia.com/blog/2023/03/21/nvidia-ai-and-omniverse-transform-automakers-workflows
# https://blogs.nvidia.com/blog/2023/1/3/mercedes-benz-next-gen-factories-omniverse/
# https://blogs.nvidia.com/blog/2023/1/3/mercedes-benz-next-gen-factories-omniverse/
# https://www.nvidia.com/en-gb/edge-computing
# https://developer.nvidia.com/isaac
# https://www.nvidia.com/en-gb/autonomous-machines/
# https://www.nvidia.com/en-us/research/robotics/
# https://www.nvidia.com/en-gb/autonomous-machines/
# https://www.nvidia.com/en-gb/edge-computing/products/igx/
# https://www.nvidia.com/en-gb/data-center/products/certified-systems/
# https://developer.nvidia.com/embedded/ecosystem
# https://developer.nvidia.com/blog/closing-the-sim-to-real-gap-training-spot-quadruped-locomotion-with-nvidia-isaac-lab/
# https://developer.nvidia.com/blog/closing-the-sim-to-real-gap-training-spot-quadruped-locomotion-with-nvidia-isaac-lab/
# https://developer.nvidia.com/blog/supercharge-robotics-workflows-with-ai-and-simulation-using-nvidia-isaac-sim-4-0-and-nvidia-isaac-lab/
# https://developer.nvidia.com/blog/supercharge-robotics-workflows-with-ai-and-simulation-using-nvidia-isaac-sim-4-0-and-nvidia-isaac-lab/
# https://nvidianews.nvidia.com/news/robotic-factories-industrial-digitalization-electronic-makers-ai-omniverse
# https://nvidianews.nvidia.com/news/robotic-factories-industrial-digitalization-electronic-makers-ai-omniverse
# https://nvidianews.nvidia.com/news/real-time-healthcare-industrial-scientific-ai-applications-igx-holoscan
# https://nvidianews.nvidia.com/news/real-time-healthcare-industrial-scientific-ai-applications-igx-holoscan
# https://blogs.nvidia.com/blog/computex-metropolis-nim/
# https://blogs.nvidia.com/blog/computex-metropolis-nim/
# https://blogs.nvidia.com/blog/alphabet-intrinsic-robotics-isaac-manipulator
# https://blogs.nvidia.com/blog/alphabet-intrinsic-robotics-isaac-manipulator
# https://blogs.nvidia.com/blog/isaac-generative-ai-manufacturing-logistics/
# https://blogs.nvidia.com/blog/isaac-generative-ai-manufacturing-logistics/
# https://developer.nvidia.com/blog/scale-ai-enabled-robotics-development-workloads-with-nvidia-osmo/
# https://developer.nvidia.com/blog/scale-ai-enabled-robotics-development-workloads-with-nvidia-osmo/
# https://blogs.nvidia.com/blog/johnson-and-johnson-medtech-ai-surgery/
# https://blogs.nvidia.com/blog/johnson-and-johnson-medtech-ai-surgery/
# https://developer.nvidia.com/blog/step-into-the-future-of-industrial-grade-edge-ai-with-nvidia-jetson-agx-orin-industrial/
# https://developer.nvidia.com/blog/step-into-the-future-of-industrial-grade-edge-ai-with-nvidia-jetson-agx-orin-industrial/
# https://www.nvidia.com/en-gb/data-center/
# https://www.nvidia.com/en-gb/data-center/gpu-cloud-computing/
# https://www.nvidia.com/en-gb/edge-computing/
# https://www.nvidia.com/en-gb/launchpad/
# https://www.nvidia.com/en-gb/data-center/products/ai-enterprise/
# https://www.nvidia.com/en-gb/data-center/dgx-systems/
# https://www.nvidia.com/en-gb/data-center/products/certified-systems/
# https://blogs.nvidia.com/blog/mlperf-training-blackwell
# https://blogs.nvidia.com/blog/mlperf-training-blackwell
# https://blogs.nvidia.com/blog/hugging-face-inference-nim-microservices-dgx-cloud/
# https://blogs.nvidia.com/blog/hugging-face-inference-nim-microservices-dgx-cloud/
# https://www.nvidia.com/en-us/events/microsoft-build/
# https://www.nvidia.com/en-us/events/microsoft-build/
# https://nvidianews.nvidia.com/news/nvidia-grace-hopper-ignites-new-era-of-ai-supercomputing
# https://nvidianews.nvidia.com/news/nvidia-grace-hopper-ignites-new-era-of-ai-supercomputing
# https://blogs.nvidia.com/blog/blackwell-scientific-computing
# https://blogs.nvidia.com/blog/blackwell-scientific-computing
# https://blogs.nvidia.com/blog/tensorrt-llm-inference-mlperf/
# https://blogs.nvidia.com/blog/tensorrt-llm-inference-mlperf/
# https://nvidianews.nvidia.com/news/networking-switches-gpu-computing-ai
# https://nvidianews.nvidia.com/news/networking-switches-gpu-computing-ai
# https://developer.nvidia.com/blog/nvidia-gb200-nvl72-delivers-trillion-parameter-llm-training-and-real-time-inference/
# https://developer.nvidia.com/blog/nvidia-gb200-nvl72-delivers-trillion-parameter-llm-training-and-real-time-inference/
# https://www.nvidia.com/en-us/data-center/dgx-b200/?nvid=nv-int-csfg-733225
# https://www.nvidia.com/en-us/data-center/dgx-b200/?nvid=nv-int-csfg-733225
# https://blogs.nvidia.com/blog/mlperf-inference-benchmark-blackwell/
# https://blogs.nvidia.com/blog/mlperf-inference-benchmark-blackwell/
# https://www.nvidia.com/en-gb/about-nvidia/
# https://www.nvidia.com/gtc
# https://www.nvidia.com/en-gb/about-nvidia/careers/
# https://nvidianews.nvidia.com
# https://www.nvidia.com/en-us/on-demand
# https://nvidianews.nvidia.com/bios
# https://www.nvidia.com/content/dam/en-zz/Solutions/about-nvidia/corporate-nvidia-in-brief.pdf
# https://images.nvidia.com/pdf/NVIDIA-Story.pdf
# https://www.nvidia.com/en-us/events/siggraph/#featured-programs
# https://www.nvidia.com/en-us/events/siggraph/#featured-programs
# https://resources.nvidia.com/gtc24-spring-best-of-highlight
# https://resources.nvidia.com/gtc24-spring-best-of-highlight
# https://www.nvidia.com/en-us/about-nvidia/
# https://www.nvidia.com/en-us/about-nvidia/
# https://blogs.nvidia.com/blog/accelerated-ai-energy-efficiency/
# https://blogs.nvidia.com/blog/accelerated-ai-energy-efficiency/
# https://blogs.nvidia.com/blog/ai-data-science-career-development/
# https://blogs.nvidia.com/blog/ai-data-science-career-development/
# https://blogs.nvidia.com/blog/selin-ornek-robot-guide-dogs/
# https://blogs.nvidia.com/blog/selin-ornek-robot-guide-dogs/
# https://blogs.nvidia.com/blog/nvidia-life-camir-ricketts/
# https://blogs.nvidia.com/blog/nvidia-life-camir-ricketts/
# https://blogs.nvidia.com/blog/te-hiku-media-maori-speech-ai/
# https://blogs.nvidia.com/blog/te-hiku-media-maori-speech-ai/
# https://blogs.nvidia.com/blog/nvidia-life-jennifer-marko/
# https://blogs.nvidia.com/blog/nvidia-life-jennifer-marko/
# https://blogs.nvidia.com/blog/jensen-huang-caltech-commencement-address/
# https://blogs.nvidia.com/blog/jensen-huang-caltech-commencement-address/
# https://www.nvidia.com/en-eu/about-nvidia/
# https://images.nvidia.com/aem-dam/Solutions/homepage/pdf/NVIDIA-Story.pdf
# https://investor.nvidia.com/home/default.aspx
# https://www.nventures.ai
# https://www.nvidia.com/en-eu/foundation/
# https://www.nvidia.com/en-eu/research/
# https://www.nvidia.com/en-eu/csr/
# https://www.nvidia.com/en-eu/technologies/
# https://www.nvidia.com/en-eu/about-nvidia/careers/
# https://nvidianews.nvidia.com/
# https://blogs.nvidia.com/
# https://developer.nvidia.com/blog/
# https://www.nvidia.com/en-eu/about-nvidia/webinar-portal/
# https://www.nvidia.com/en-eu/preferences/email-signup/
# https://www.nvidia.com/en-us/events/
# https://www.nvidia.com/en-us/gtc/?for=emea
# https://www.nvidia.com/en-us/on-demand/
# https://developer.nvidia.com/
# https://www.nvidia.com/en-eu/about-nvidia/partners/
# https://www.nvidia.com/en-eu/executive-insights/
# https://www.nvidia.com/en-eu/startups/
# https://www.nvidia.com/en-us/programs/isv/
# https://docs.nvidia.com/
# https://www.nvidia.com/en-eu/training/
# https://academy.nvidia.com/en/
# https://www.nvidia.com/en-eu/ai-data-science/professional-services/
# https://www.facebook.com/NVIDIAGeForceUK/
# https://www.twitch.tv/nvidia
# https://twitter.com/NVIDIAGeForceUK
# https://www.youtube.com/channel/UCL-g3eGJi1omSDSz48AML-g
# https://www.nvidia.com/en-us/location-selector/
# https://www.nvidia.com/en-eu/about-nvidia/privacy-policy/
# https://www.nvidia.com/en-eu/privacy-center/
# https://www.nvidia.com/en-eu/about-nvidia/terms-of-service/
# https://www.nvidia.com/en-eu/about-nvidia/accessibility/
# https://www.nvidia.com/en-eu/about-nvidia/company-policies/
# https://www.nvidia.com/en-eu/security/
# https://www.nvidia.com/en-eu/contact/

# %%
def get_links(url):
    website = Website(url)
    completion = openai.chat.completions.create(
    model = 'gpt-4o-mini',
    messages=[
        {"role": "system", "content": link_system_prompt},
        {"role": "user", "content": get_links_user_prompt(website)}
    ],
        response_format={"type": "json_object"}
    )
    result = completion.choices[0].message.content
    return json.loads(result)

# %%
get_links("https://www.nvidia.com/en-me/")
# Out:
# {'links': [{'type': 'about page',
#    'url': 'https://www.nvidia.com/en-us/about-nvidia/'},
#   {'type': 'careers page',
#    'url': 'https://www.nvidia.com/en-us/about-nvidia/careers/'},
#   {'type': 'about page', 'url': 'https://www.nvidia.com/en-eu/about-nvidia/'},
#   {'type': 'careers page',
#    'url': 'https://www.nvidia.com/en-eu/about-nvidia/careers/'},
#   {'type': 'products page', 'url': 'https://www.nvidia.com/en-me/geforce/'},
#   {'type': 'products page', 'url': 'https://www.nvidia.com/en-us/gtc'},
#   {'type': 'products page',
#    'url': 'https://www.nvidia.com/en-gb/lp/high-performance-computing/hpc-ai-cloud-computing-ebook'},
#   {'type': 'company policies page',
#    'url': 'https://www.nvidia.com/en-eu/about-nvidia/company-policies/'}]}

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result+= Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links['links']:
        result+= f"{link['type']}"
        result+= Website(link['url']).get_contents()
    return result

# %%
# get_all_details("https://www.nvidia.com/en-me/")

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url, model, tone):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short {tone.lower()} brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:20_000] # Truncate if more than 20,000 characters
    return user_prompt

# %%
def generate_brochure(company_name, url, model, tone):
    # Initialize response variable
    response = ""
    
    # Get the user prompt for the brochure
    user_prompt = get_brochure_user_prompt(company_name, url, model, tone)
    
    if model == 'GPT':
        # Get the full response from GPT (no streaming)
        result = openai.chat.completions.create(
            model='gpt-4o-mini',
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        # Extract the content of the response
        response = result.choices[0].message.content
    
    elif model == 'Claude':
        # Get the full response from Claude (no streaming)
        result = claude.messages.create(
            model='claude-3-haiku-20240307',
            max_tokens=1000,
            temperature=0.7,
            system=system_prompt,
            messages=[
                {"role": "user", "content": user_prompt}
            ]
        )
        # Extract the content of the response
        response = result.content[0].text
    
    # Return the response directly for Gradio to render
    return response

# %%
view = gr.Interface(
    fn=generate_brochure,
    inputs=[
        gr.Textbox(label="Company name"),
        gr.Textbox(label="Landing page URL including http:// or https://"),
        gr.Dropdown(choices=["GPT", "Claude"], label="Select Model"),
        gr.Textbox(label="Tone (e.g., Professional, Friendly, etc.)")
    ],
    outputs=gr.Markdown(label="Brochure:"),
    flagging_mode="never"
)
view.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7888
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7888/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
